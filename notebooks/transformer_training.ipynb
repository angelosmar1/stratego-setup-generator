# %% [markdown]
# ## Imports

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.model_selection import KFold

import torch
from torch import nn
from torch.utils.data import DataLoader, Subset
from torch.optim.lr_scheduler import StepLR

# %%
import sys
sys.path.append('..')

from src.generators import TransformerGenerator
from src.training import train, plot_metric_curves, LearningRateCallback, save_model, log_loss_seq
from src.training import SetupsDataset, SetupsDatasetWrapper
from src.plotting import create_plot_grid

# %% [markdown]
# ## Tuning parameters and number of epochs using cross-validation

# %%
setups_df = pd.read_csv("../data/setups.csv", header=None, dtype='uint8').drop_duplicates().reset_index(drop=True)
setups_dataset = SetupsDataset(setups_df.to_numpy())

# %%
criterion =  nn.CrossEntropyLoss()
num_epochs = 250
batch_size = 128

num_folds = 5
seed = 1

mirror_prob = 0.5

# %%
model_params = {"embedding_dim": 128,
                "num_layers": 3,
                "num_heads": 8,
                "dropout": 0.3
                }

# %%
kfold = KFold(n_splits=num_folds, shuffle=True, random_state=seed)

training_history = []

torch.manual_seed(seed)


for fold_number, (train_indices, val_indices) in enumerate(kfold.split(setups_dataset)):

    print(f"fold {fold_number + 1}")

    model = TransformerGenerator(**model_params)
    optimizer = torch.optim.AdamW(model.parameters(), lr=0.001)
    lr_scheduler = StepLR(optimizer, step_size=1, gamma=0.98)

    train_dataset_wrapper = SetupsDatasetWrapper(setups_dataset, mirror_prob=mirror_prob, random_state=seed)
    val_dataset_wrapper = SetupsDatasetWrapper(setups_dataset)

    train_dataloader = DataLoader(Subset(train_dataset_wrapper, train_indices), batch_size=batch_size, shuffle=True,
                                  generator=torch.Generator().manual_seed(seed))
    val_dataloader = DataLoader(Subset(val_dataset_wrapper, val_indices), batch_size=batch_size, shuffle=False)

    metrics_per_epoch = train(model, train_dataloader, num_epochs, optimizer, criterion,
                              val_dataloader, eval_metrics=[("Cross Entropy", log_loss_seq)],
                              callbacks=[LearningRateCallback(lr_scheduler, verbose=True)])

    training_history.append(metrics_per_epoch)


mean_train_metric = np.mean([fold["train_metrics"]["Cross Entropy"] for fold in training_history], axis=0)
mean_val_metric = np.mean([fold["val_metrics"]["Cross Entropy"] for fold in training_history], axis=0)
best_epoch = np.argmin(mean_val_metric)
best_score = mean_val_metric[best_epoch]

print("----------------------------------")
print(f"best epoch {best_epoch}")
print(f"best mean score {best_score}")
# Out:
# fold 1
# Using device 'cuda'
# Epoch: 1, Train Cross Entropy: 1.65406, Val Cross Entropy: 1.65513
# Learning Rate: [0.00098]
# Epoch: 2, Train Cross Entropy: 1.60688, Val Cross Entropy: 1.60837
# Learning Rate: [0.0009603999999999999]
# Epoch: 3, Train Cross Entropy: 1.59404, Val Cross Entropy: 1.59691
# Learning Rate: [0.0009411919999999999]
# Epoch: 4, Train Cross Entropy: 1.57742, Val Cross Entropy: 1.58104
# Learning Rate: [0.0009223681599999998]
# Epoch: 5, Train Cross Entropy: 1.56491, Val Cross Entropy: 1.5703
# Learning Rate: [0.0009039207967999998]
# Epoch: 6, Train Cross Entropy: 1.55559, Val Cross Entropy: 1.56205
# Learning Rate: [0.0008858423808639998]
# Epoch: 7, Train Cross Entropy: 1.54782, Val Cross Entropy: 1.55489
# Learning Rate: [0.0008681255332467198]
# Epoch: 8, Train Cross Entropy: 1.5432, Val Cross Entropy: 1.55188
# Learning Rate: [0.0008507630225817853]
# Epoch: 9, Train Cross Entropy: 1.53477, Val Cross Entropy: 1.54365
# Learning Rate: [0.0008337477621301496]
# Epoch: 10, Train Cross Entropy: 1.52766, Val Cross Entropy: 1.53865
# Learning Rate: [0.0008170728068875465]
# Epoch: 11, Train Cross Entropy: 1.52178, Val Cross Entropy: 1.53272
# Learning Rate: [0.0008007313507497956]
# Epoch: 12, Train Cross Entropy: 1.51891, Val Cross Entropy: 1.53042
# Learning Rate: [0.0007847167237347997]
# Epoch: 13, Train Cross Entropy: 1.51436, Val Cross Entropy: 1.52717
# Learning Rate: [0.0007690223892601037]
# Epoch: 14, Train Cross Entropy: 1.51095, Val Cross Entropy: 1.52508
# Learning Rate: [0.0007536419414749016]
# Epoch: 15, Train Cross Entropy: 1.50442, Val Cross Entropy: 1.52002
# Learning Rate: [0.0007385691026454036]
# Epoch: 16, Train Cross Entropy: 1.50268, Val Cross Entropy: 1.51813
# Learning Rate: [0.0007237977205924955]
# Epoch: 17, Train Cross Entropy: 1.49882, Val Cross Entropy: 1.51556
# Learning Rate: [0.0007093217661806456]
# Epoch: 18, Train Cross Entropy: 1.49618, Val Cross Entropy: 1.51318
# Learning Rate: [0.0006951353308570327]
# Epoch: 19, Train Cross Entropy: 1.48993, Val Cross Entropy: 1.50739
# Learning Rate: [0.000681232624239892]
# Epoch: 20, Train Cross Entropy: 1.48787, Val Cross Entropy: 1.50724
# Learning Rate: [0.0006676079717550942]
# Epoch: 21, Train Cross Entropy: 1.48253, Val Cross Entropy: 1.50237
# Learning Rate: [0.0006542558123199924]
# Epoch: 22, Train Cross Entropy: 1.48228, Val Cross Entropy: 1.50236
# Learning Rate: [0.0006411706960735925]
# Epoch: 23, Train Cross Entropy: 1.47962, Val Cross Entropy: 1.5011
# Learning Rate: [0.0006283472821521206]
# Epoch: 24, Train Cross Entropy: 1.47837, Val Cross Entropy: 1.50048
# Learning Rate: [0.0006157803365090782]
# Epoch: 25, Train Cross Entropy: 1.47533, Val Cross Entropy: 1.50009
# Learning Rate: [0.0006034647297788967]
# Epoch: 26, Train Cross Entropy: 1.47072, Val Cross Entropy: 1.49431
# Learning Rate: [0.0005913954351833187]
# Epoch: 27, Train Cross Entropy: 1.46934, Val Cross Entropy: 1.49352
# Learning Rate: [0.0005795675264796523]
# Epoch: 28, Train Cross Entropy: 1.46787, Val Cross Entropy: 1.49282
# Learning Rate: [0.0005679761759500593]
# Epoch: 29, Train Cross Entropy: 1.4668, Val Cross Entropy: 1.49149
# Learning Rate: [0.0005566166524310581]
# Epoch: 30, Train Cross Entropy: 1.46374, Val Cross Entropy: 1.4898
# Learning Rate: [0.0005454843193824369]
# Epoch: 31, Train Cross Entropy: 1.46133, Val Cross Entropy: 1.48832
# Learning Rate: [0.0005345746329947881]
# Epoch: 32, Train Cross Entropy: 1.4608, Val Cross Entropy: 1.48824
# Learning Rate: [0.0005238831403348923]
# Epoch: 33, Train Cross Entropy: 1.46006, Val Cross Entropy: 1.48674
# Learning Rate: [0.0005134054775281945]
# Epoch: 34, Train Cross Entropy: 1.45669, Val Cross Entropy: 1.48468
# Learning Rate: [0.0005031373679776305]
# Epoch: 35, Train Cross Entropy: 1.4555, Val Cross Entropy: 1.48277
# Learning Rate: [0.0004930746206180779]
# Epoch: 36, Train Cross Entropy: 1.45518, Val Cross Entropy: 1.48216
# Learning Rate: [0.00048321312820571636]
# Epoch: 37, Train Cross Entropy: 1.45317, Val Cross Entropy: 1.48089
# Learning Rate: [0.00047354886564160203]
# Epoch: 38, Train Cross Entropy: 1.45047, Val Cross Entropy: 1.4801
# Learning Rate: [0.00046407788832877]
# Epoch: 39, Train Cross Entropy: 1.4504, Val Cross Entropy: 1.48069
# Learning Rate: [0.0004547963305621946]
# Epoch: 40, Train Cross Entropy: 1.44682, Val Cross Entropy: 1.47678
# Learning Rate: [0.0004457004039509507]
# Epoch: 41, Train Cross Entropy: 1.44623, Val Cross Entropy: 1.47769
# Learning Rate: [0.0004367863958719317]
# Epoch: 42, Train Cross Entropy: 1.44546, Val Cross Entropy: 1.47822
# Learning Rate: [0.00042805066795449306]
# Epoch: 43, Train Cross Entropy: 1.44665, Val Cross Entropy: 1.47625
# Learning Rate: [0.0004194896545954032]
# Epoch: 44, Train Cross Entropy: 1.44141, Val Cross Entropy: 1.47376
# Learning Rate: [0.0004110998615034951]
# Epoch: 45, Train Cross Entropy: 1.44175, Val Cross Entropy: 1.47363
# Learning Rate: [0.00040287786427342523]
# Epoch: 46, Train Cross Entropy: 1.43966, Val Cross Entropy: 1.47363
# Learning Rate: [0.00039482030698795675]
# Epoch: 47, Train Cross Entropy: 1.43852, Val Cross Entropy: 1.47222
# Learning Rate: [0.0003869239008481976]
# Epoch: 48, Train Cross Entropy: 1.43688, Val Cross Entropy: 1.4721
# Learning Rate: [0.0003791854228312336]
# Epoch: 49, Train Cross Entropy: 1.43597, Val Cross Entropy: 1.47116
# Learning Rate: [0.00037160171437460894]
# Epoch: 50, Train Cross Entropy: 1.43829, Val Cross Entropy: 1.4717
# Learning Rate: [0.00036416968008711674]
# Epoch: 51, Train Cross Entropy: 1.43366, Val Cross Entropy: 1.46837
# Learning Rate: [0.0003568862864853744]
# Epoch: 52, Train Cross Entropy: 1.43424, Val Cross Entropy: 1.46874
# Learning Rate: [0.0003497485607556669]
# Epoch: 53, Train Cross Entropy: 1.43461, Val Cross Entropy: 1.46896
# Learning Rate: [0.00034275358954055353]
# Epoch: 54, Train Cross Entropy: 1.43154, Val Cross Entropy: 1.46847
# Learning Rate: [0.00033589851774974244]
# Epoch: 55, Train Cross Entropy: 1.42999, Val Cross Entropy: 1.46672
# Learning Rate: [0.0003291805473947476]
# Epoch: 56, Train Cross Entropy: 1.43025, Val Cross Entropy: 1.46885
# Learning Rate: [0.0003225969364468526]
# Epoch: 57, Train Cross Entropy: 1.42882, Val Cross Entropy: 1.46636
# Learning Rate: [0.00031614499771791553]
# Epoch: 58, Train Cross Entropy: 1.4297, Val Cross Entropy: 1.465
# Learning Rate: [0.0003098220977635572]
# Epoch: 59, Train Cross Entropy: 1.42736, Val Cross Entropy: 1.46498
# Learning Rate: [0.00030362565580828606]
# Epoch: 60, Train Cross Entropy: 1.42505, Val Cross Entropy: 1.46463
# Learning Rate: [0.0002975531426921203]
# Epoch: 61, Train Cross Entropy: 1.42453, Val Cross Entropy: 1.4632
# Learning Rate: [0.0002916020798382779]
# Epoch: 62, Train Cross Entropy: 1.42582, Val Cross Entropy: 1.46353
# Learning Rate: [0.0002857700382415123]
# Epoch: 63, Train Cross Entropy: 1.42371, Val Cross Entropy: 1.46357
# Learning Rate: [0.0002800546374766821]
# Epoch: 64, Train Cross Entropy: 1.42183, Val Cross Entropy: 1.46341
# Learning Rate: [0.00027445354472714845]
# Epoch: 65, Train Cross Entropy: 1.42227, Val Cross Entropy: 1.46249
# Learning Rate: [0.0002689644738326055]
# Epoch: 66, Train Cross Entropy: 1.42116, Val Cross Entropy: 1.46107
# Learning Rate: [0.00026358518435595335]
# Epoch: 67, Train Cross Entropy: 1.41994, Val Cross Entropy: 1.4607
# Learning Rate: [0.00025831348066883425]
# Epoch: 68, Train Cross Entropy: 1.42019, Val Cross Entropy: 1.462
# Learning Rate: [0.00025314721105545757]
# Epoch: 69, Train Cross Entropy: 1.41878, Val Cross Entropy: 1.46085
# Learning Rate: [0.00024808426683434843]
# Epoch: 70, Train Cross Entropy: 1.4189, Val Cross Entropy: 1.45999
# Learning Rate: [0.00024312258149766146]
# Epoch: 71, Train Cross Entropy: 1.41671, Val Cross Entropy: 1.45984
# Learning Rate: [0.00023826012986770823]
# Epoch: 72, Train Cross Entropy: 1.4183, Val Cross Entropy: 1.46133
# Learning Rate: [0.00023349492727035406]
# Epoch: 73, Train Cross Entropy: 1.41643, Val Cross Entropy: 1.45803
# Learning Rate: [0.00022882502872494697]
# Epoch: 74, Train Cross Entropy: 1.41661, Val Cross Entropy: 1.45867
# Learning Rate: [0.00022424852815044804]
# Epoch: 75, Train Cross Entropy: 1.41623, Val Cross Entropy: 1.46253
# Learning Rate: [0.00021976355758743907]
# Epoch: 76, Train Cross Entropy: 1.41688, Val Cross Entropy: 1.46073
# Learning Rate: [0.00021536828643569029]
# Epoch: 77, Train Cross Entropy: 1.41345, Val Cross Entropy: 1.45755
# Learning Rate: [0.00021106092070697648]
# Epoch: 78, Train Cross Entropy: 1.41387, Val Cross Entropy: 1.4572
# Learning Rate: [0.00020683970229283695]
# Epoch: 79, Train Cross Entropy: 1.41225, Val Cross Entropy: 1.45801
# Learning Rate: [0.0002027029082469802]
# Epoch: 80, Train Cross Entropy: 1.41165, Val Cross Entropy: 1.4571
# Learning Rate: [0.0001986488500820406]
# Epoch: 81, Train Cross Entropy: 1.41147, Val Cross Entropy: 1.45579
# Learning Rate: [0.00019467587308039978]
# Epoch: 82, Train Cross Entropy: 1.41255, Val Cross Entropy: 1.45853
# Learning Rate: [0.00019078235561879178]
# Epoch: 83, Train Cross Entropy: 1.41095, Val Cross Entropy: 1.45612
# Learning Rate: [0.00018696670850641594]
# Epoch: 84, Train Cross Entropy: 1.41058, Val Cross Entropy: 1.4557
# Learning Rate: [0.0001832273743362876]
# Epoch: 85, Train Cross Entropy: 1.41044, Val Cross Entropy: 1.45541
# Learning Rate: [0.00017956282684956185]
# Epoch: 86, Train Cross Entropy: 1.40936, Val Cross Entropy: 1.45506
# Learning Rate: [0.0001759715703125706]
# Epoch: 87, Train Cross Entropy: 1.40903, Val Cross Entropy: 1.45466
# Learning Rate: [0.0001724521389063192]
# Epoch: 88, Train Cross Entropy: 1.4087, Val Cross Entropy: 1.45397
# Learning Rate: [0.00016900309612819282]
# Epoch: 89, Train Cross Entropy: 1.40759, Val Cross Entropy: 1.45473
# Learning Rate: [0.00016562303420562897]
# Epoch: 90, Train Cross Entropy: 1.40764, Val Cross Entropy: 1.45367
# Learning Rate: [0.0001623105735215164]
# Epoch: 91, Train Cross Entropy: 1.40765, Val Cross Entropy: 1.45578
# Learning Rate: [0.00015906436205108607]
# Epoch: 92, Train Cross Entropy: 1.40661, Val Cross Entropy: 1.45296
# Learning Rate: [0.00015588307481006434]
# Epoch: 93, Train Cross Entropy: 1.40717, Val Cross Entropy: 1.45576
# Learning Rate: [0.00015276541331386305]
# Epoch: 94, Train Cross Entropy: 1.40615, Val Cross Entropy: 1.45309
# Learning Rate: [0.00014971010504758578]
# Epoch: 95, Train Cross Entropy: 1.40639, Val Cross Entropy: 1.45425
# Learning Rate: [0.00014671590294663406]
# Epoch: 96, Train Cross Entropy: 1.40512, Val Cross Entropy: 1.45251
# Learning Rate: [0.00014378158488770137]
# Epoch: 97, Train Cross Entropy: 1.40513, Val Cross Entropy: 1.4528
# Learning Rate: [0.00014090595318994734]
# Epoch: 98, Train Cross Entropy: 1.40448, Val Cross Entropy: 1.45265
# Learning Rate: [0.0001380878341261484]
# Epoch: 99, Train Cross Entropy: 1.40377, Val Cross Entropy: 1.4517
# Learning Rate: [0.00013532607744362542]
# Epoch: 100, Train Cross Entropy: 1.40418, Val Cross Entropy: 1.45315
# Learning Rate: [0.00013261955589475292]
# Epoch: 101, Train Cross Entropy: 1.4048, Val Cross Entropy: 1.45227
# Learning Rate: [0.00012996716477685786]
# Epoch: 102, Train Cross Entropy: 1.40255, Val Cross Entropy: 1.45035
# Learning Rate: [0.0001273678214813207]
# Epoch: 103, Train Cross Entropy: 1.40291, Val Cross Entropy: 1.45246
# Learning Rate: [0.00012482046505169427]
# Epoch: 104, Train Cross Entropy: 1.40374, Val Cross Entropy: 1.45179
# Learning Rate: [0.00012232405575066037]
# Epoch: 105, Train Cross Entropy: 1.40189, Val Cross Entropy: 1.45184
# Learning Rate: [0.00011987757463564716]
# Epoch: 106, Train Cross Entropy: 1.40238, Val Cross Entropy: 1.44969
# Learning Rate: [0.00011748002314293422]
# Epoch: 107, Train Cross Entropy: 1.40085, Val Cross Entropy: 1.45022
# Learning Rate: [0.00011513042268007553]
# Epoch: 108, Train Cross Entropy: 1.40134, Val Cross Entropy: 1.45005
# Learning Rate: [0.00011282781422647401]
# Epoch: 109, Train Cross Entropy: 1.40047, Val Cross Entropy: 1.45029
# Learning Rate: [0.00011057125794194453]
# Epoch: 110, Train Cross Entropy: 1.40076, Val Cross Entropy: 1.4499
# Learning Rate: [0.00010835983278310564]
# Epoch: 111, Train Cross Entropy: 1.39965, Val Cross Entropy: 1.44943
# Learning Rate: [0.00010619263612744353]
# Epoch: 112, Train Cross Entropy: 1.39978, Val Cross Entropy: 1.45044
# Learning Rate: [0.00010406878340489466]
# Epoch: 113, Train Cross Entropy: 1.39996, Val Cross Entropy: 1.44868
# Learning Rate: [0.00010198740773679677]
# Epoch: 114, Train Cross Entropy: 1.39978, Val Cross Entropy: 1.44928
# Learning Rate: [9.994765958206083e-05]
# Epoch: 115, Train Cross Entropy: 1.39876, Val Cross Entropy: 1.44828
# Learning Rate: [9.79487063904196e-05]
# Epoch: 116, Train Cross Entropy: 1.39982, Val Cross Entropy: 1.45178
# Learning Rate: [9.598973226261122e-05]
# Epoch: 117, Train Cross Entropy: 1.39945, Val Cross Entropy: 1.4481
# Learning Rate: [9.4069937617359e-05]
# Epoch: 118, Train Cross Entropy: 1.39804, Val Cross Entropy: 1.44914
# Learning Rate: [9.218853886501181e-05]
# Epoch: 119, Train Cross Entropy: 1.39809, Val Cross Entropy: 1.44841
# Learning Rate: [9.034476808771157e-05]
# Epoch: 120, Train Cross Entropy: 1.3976, Val Cross Entropy: 1.44906
# Learning Rate: [8.853787272595733e-05]
# Epoch: 121, Train Cross Entropy: 1.39795, Val Cross Entropy: 1.44824
# Learning Rate: [8.676711527143819e-05]
# Epoch: 122, Train Cross Entropy: 1.39819, Val Cross Entropy: 1.44965
# Learning Rate: [8.503177296600943e-05]
# Epoch: 123, Train Cross Entropy: 1.39717, Val Cross Entropy: 1.44798
# Learning Rate: [8.333113750668924e-05]
# Epoch: 124, Train Cross Entropy: 1.39727, Val Cross Entropy: 1.44884
# Learning Rate: [8.166451475655545e-05]
# Epoch: 125, Train Cross Entropy: 1.39802, Val Cross Entropy: 1.44818
# Learning Rate: [8.003122446142433e-05]
# Epoch: 126, Train Cross Entropy: 1.3961, Val Cross Entropy: 1.44787
# Learning Rate: [7.843059997219585e-05]
# Epoch: 127, Train Cross Entropy: 1.39624, Val Cross Entropy: 1.44763
# Learning Rate: [7.686198797275193e-05]
# Epoch: 128, Train Cross Entropy: 1.39681, Val Cross Entropy: 1.44725
# Learning Rate: [7.532474821329689e-05]
# Epoch: 129, Train Cross Entropy: 1.39595, Val Cross Entropy: 1.44898
# Learning Rate: [7.381825324903095e-05]
# Epoch: 130, Train Cross Entropy: 1.39575, Val Cross Entropy: 1.44614
# Learning Rate: [7.234188818405033e-05]
# Epoch: 131, Train Cross Entropy: 1.39524, Val Cross Entropy: 1.44661
# Learning Rate: [7.089505042036933e-05]
# Epoch: 132, Train Cross Entropy: 1.39611, Val Cross Entropy: 1.44868
# Learning Rate: [6.947714941196194e-05]
# Epoch: 133, Train Cross Entropy: 1.39502, Val Cross Entropy: 1.44625
# Learning Rate: [6.808760642372271e-05]
# Epoch: 134, Train Cross Entropy: 1.39543, Val Cross Entropy: 1.44651
# Learning Rate: [6.672585429524825e-05]
# Epoch: 135, Train Cross Entropy: 1.39545, Val Cross Entropy: 1.44857
# Learning Rate: [6.539133720934329e-05]
# Epoch: 136, Train Cross Entropy: 1.39555, Val Cross Entropy: 1.4475
# Learning Rate: [6.408351046515642e-05]
# Epoch: 137, Train Cross Entropy: 1.39455, Val Cross Entropy: 1.44651
# Learning Rate: [6.28018402558533e-05]
# Epoch: 138, Train Cross Entropy: 1.39424, Val Cross Entropy: 1.44669
# Learning Rate: [6.154580345073623e-05]
# Epoch: 139, Train Cross Entropy: 1.3939, Val Cross Entropy: 1.44711
# Learning Rate: [6.031488738172151e-05]
# Epoch: 140, Train Cross Entropy: 1.3938, Val Cross Entropy: 1.44581
# Learning Rate: [5.910858963408708e-05]
# Epoch: 141, Train Cross Entropy: 1.39398, Val Cross Entropy: 1.44672
# Learning Rate: [5.7926417841405336e-05]
# Epoch: 142, Train Cross Entropy: 1.39378, Val Cross Entropy: 1.44644
# Learning Rate: [5.676788948457723e-05]
# Epoch: 143, Train Cross Entropy: 1.39386, Val Cross Entropy: 1.4459
# Learning Rate: [5.563253169488568e-05]
# Epoch: 144, Train Cross Entropy: 1.39351, Val Cross Entropy: 1.4452
# Learning Rate: [5.4519881060987966e-05]
# Epoch: 145, Train Cross Entropy: 1.39338, Val Cross Entropy: 1.44622
# Learning Rate: [5.3429483439768204e-05]
# Epoch: 146, Train Cross Entropy: 1.3932, Val Cross Entropy: 1.44724
# Learning Rate: [5.236089377097284e-05]
# Epoch: 147, Train Cross Entropy: 1.39279, Val Cross Entropy: 1.4468
# Learning Rate: [5.131367589555338e-05]
# Epoch: 148, Train Cross Entropy: 1.39268, Val Cross Entropy: 1.4463
# Learning Rate: [5.0287402377642316e-05]
# Epoch: 149, Train Cross Entropy: 1.39316, Val Cross Entropy: 1.44665
# Learning Rate: [4.928165433008947e-05]
# Epoch: 150, Train Cross Entropy: 1.39276, Val Cross Entropy: 1.44614
# Learning Rate: [4.829602124348768e-05]
# Epoch: 151, Train Cross Entropy: 1.39281, Val Cross Entropy: 1.44736
# Learning Rate: [4.733010081861793e-05]
# Epoch: 152, Train Cross Entropy: 1.3934, Val Cross Entropy: 1.44531
# Learning Rate: [4.638349880224557e-05]
# Epoch: 153, Train Cross Entropy: 1.3927, Val Cross Entropy: 1.44595
# Learning Rate: [4.5455828826200656e-05]
# Epoch: 154, Train Cross Entropy: 1.39227, Val Cross Entropy: 1.44648
# Learning Rate: [4.454671224967664e-05]
# Epoch: 155, Train Cross Entropy: 1.39239, Val Cross Entropy: 1.44555
# Learning Rate: [4.3655778004683106e-05]
# Epoch: 156, Train Cross Entropy: 1.39184, Val Cross Entropy: 1.44583
# Learning Rate: [4.278266244458944e-05]
# Epoch: 157, Train Cross Entropy: 1.39268, Val Cross Entropy: 1.44453
# Learning Rate: [4.192700919569765e-05]
# Epoch: 158, Train Cross Entropy: 1.39249, Val Cross Entropy: 1.44567
# Learning Rate: [4.10884690117837e-05]
# Epoch: 159, Train Cross Entropy: 1.39147, Val Cross Entropy: 1.44535
# Learning Rate: [4.0266699631548025e-05]
# Epoch: 160, Train Cross Entropy: 1.3923, Val Cross Entropy: 1.44467
# Learning Rate: [3.9461365638917066e-05]
# Epoch: 161, Train Cross Entropy: 1.39129, Val Cross Entropy: 1.44474
# Learning Rate: [3.867213832613872e-05]
# Epoch: 162, Train Cross Entropy: 1.39117, Val Cross Entropy: 1.44465
# Learning Rate: [3.789869555961595e-05]
# Epoch: 163, Train Cross Entropy: 1.39135, Val Cross Entropy: 1.44495
# Learning Rate: [3.714072164842363e-05]
# Epoch: 164, Train Cross Entropy: 1.39138, Val Cross Entropy: 1.44539
# Learning Rate: [3.6397907215455155e-05]
# Epoch: 165, Train Cross Entropy: 1.39117, Val Cross Entropy: 1.44436
# Learning Rate: [3.5669949071146054e-05]
# Epoch: 166, Train Cross Entropy: 1.3915, Val Cross Entropy: 1.4449
# Learning Rate: [3.495655008972313e-05]
# Epoch: 167, Train Cross Entropy: 1.39071, Val Cross Entropy: 1.44462
# Learning Rate: [3.425741908792867e-05]
# Epoch: 168, Train Cross Entropy: 1.3909, Val Cross Entropy: 1.44523
# Learning Rate: [3.3572270706170096e-05]
# Epoch: 169, Train Cross Entropy: 1.39056, Val Cross Entropy: 1.44488
# Learning Rate: [3.290082529204669e-05]
# Epoch: 170, Train Cross Entropy: 1.39113, Val Cross Entropy: 1.44512
# Learning Rate: [3.2242808786205754e-05]
# Epoch: 171, Train Cross Entropy: 1.3902, Val Cross Entropy: 1.44464
# Learning Rate: [3.1597952610481636e-05]
# Epoch: 172, Train Cross Entropy: 1.39021, Val Cross Entropy: 1.44465
# Learning Rate: [3.0965993558272005e-05]
# Epoch: 173, Train Cross Entropy: 1.39043, Val Cross Entropy: 1.44468
# Learning Rate: [3.0346673687106565e-05]
# Epoch: 174, Train Cross Entropy: 1.39042, Val Cross Entropy: 1.44477
# Learning Rate: [2.9739740213364434e-05]
# Epoch: 175, Train Cross Entropy: 1.39075, Val Cross Entropy: 1.44412
# Learning Rate: [2.9144945409097143e-05]
# Epoch: 176, Train Cross Entropy: 1.39016, Val Cross Entropy: 1.4445
# Learning Rate: [2.8562046500915198e-05]
# Epoch: 177, Train Cross Entropy: 1.39021, Val Cross Entropy: 1.44428
# Learning Rate: [2.7990805570896893e-05]
# Epoch: 178, Train Cross Entropy: 1.38946, Val Cross Entropy: 1.44486
# Learning Rate: [2.7430989459478954e-05]
# Epoch: 179, Train Cross Entropy: 1.38985, Val Cross Entropy: 1.44451
# Learning Rate: [2.6882369670289372e-05]
# Epoch: 180, Train Cross Entropy: 1.39027, Val Cross Entropy: 1.44459
# Learning Rate: [2.6344722276883584e-05]
# Epoch: 181, Train Cross Entropy: 1.39012, Val Cross Entropy: 1.4445
# Learning Rate: [2.581782783134591e-05]
# Epoch: 182, Train Cross Entropy: 1.38956, Val Cross Entropy: 1.44378
# Learning Rate: [2.530147127471899e-05]
# Epoch: 183, Train Cross Entropy: 1.38959, Val Cross Entropy: 1.44352
# Learning Rate: [2.479544184922461e-05]
# Epoch: 184, Train Cross Entropy: 1.38999, Val Cross Entropy: 1.44381
# Learning Rate: [2.4299533012240118e-05]
# Epoch: 185, Train Cross Entropy: 1.38979, Val Cross Entropy: 1.44398
# Learning Rate: [2.3813542351995315e-05]
# Epoch: 186, Train Cross Entropy: 1.38962, Val Cross Entropy: 1.44468
# Learning Rate: [2.333727150495541e-05]
# Epoch: 187, Train Cross Entropy: 1.38988, Val Cross Entropy: 1.44424
# Learning Rate: [2.28705260748563e-05]
# Epoch: 188, Train Cross Entropy: 1.38927, Val Cross Entropy: 1.44427
# Learning Rate: [2.2413115553359176e-05]
# Epoch: 189, Train Cross Entropy: 1.38927, Val Cross Entropy: 1.4442
# Learning Rate: [2.196485324229199e-05]
# Epoch: 190, Train Cross Entropy: 1.38929, Val Cross Entropy: 1.44418
# Learning Rate: [2.152555617744615e-05]
# Epoch: 191, Train Cross Entropy: 1.38936, Val Cross Entropy: 1.44408
# Learning Rate: [2.109504505389723e-05]
# Epoch: 192, Train Cross Entropy: 1.38898, Val Cross Entropy: 1.44407
# Learning Rate: [2.0673144152819283e-05]
# Epoch: 193, Train Cross Entropy: 1.38877, Val Cross Entropy: 1.44367
# Learning Rate: [2.0259681269762897e-05]
# Epoch: 194, Train Cross Entropy: 1.38924, Val Cross Entropy: 1.44436
# Learning Rate: [1.985448764436764e-05]
# Epoch: 195, Train Cross Entropy: 1.38911, Val Cross Entropy: 1.44459
# Learning Rate: [1.9457397891480286e-05]
# Epoch: 196, Train Cross Entropy: 1.38902, Val Cross Entropy: 1.44431
# Learning Rate: [1.906824993365068e-05]
# Epoch: 197, Train Cross Entropy: 1.38903, Val Cross Entropy: 1.44341
# Learning Rate: [1.8686884934977666e-05]
# Epoch: 198, Train Cross Entropy: 1.38875, Val Cross Entropy: 1.44407
# Learning Rate: [1.8313147236278114e-05]
# Epoch: 199, Train Cross Entropy: 1.38917, Val Cross Entropy: 1.4439
# Learning Rate: [1.794688429155255e-05]
# Epoch: 200, Train Cross Entropy: 1.38909, Val Cross Entropy: 1.44391
# Learning Rate: [1.75879466057215e-05]
# Epoch: 201, Train Cross Entropy: 1.38898, Val Cross Entropy: 1.44401
# Learning Rate: [1.7236187673607072e-05]
# Epoch: 202, Train Cross Entropy: 1.38871, Val Cross Entropy: 1.44402
# Learning Rate: [1.689146392013493e-05]
# Epoch: 203, Train Cross Entropy: 1.38843, Val Cross Entropy: 1.44382
# Learning Rate: [1.6553634641732232e-05]
# Epoch: 204, Train Cross Entropy: 1.38868, Val Cross Entropy: 1.4433
# Learning Rate: [1.6222561948897586e-05]
# Epoch: 205, Train Cross Entropy: 1.38882, Val Cross Entropy: 1.44406
# Learning Rate: [1.5898110709919635e-05]
# Epoch: 206, Train Cross Entropy: 1.3888, Val Cross Entropy: 1.44298
# Learning Rate: [1.5580148495721243e-05]
# Epoch: 207, Train Cross Entropy: 1.38844, Val Cross Entropy: 1.44358
# Learning Rate: [1.526854552580682e-05]
# Epoch: 208, Train Cross Entropy: 1.38847, Val Cross Entropy: 1.44391
# Learning Rate: [1.4963174615290682e-05]
# Epoch: 209, Train Cross Entropy: 1.38822, Val Cross Entropy: 1.44315
# Learning Rate: [1.4663911122984868e-05]
# Epoch: 210, Train Cross Entropy: 1.38842, Val Cross Entropy: 1.44333
# Learning Rate: [1.437063290052517e-05]
# Epoch: 211, Train Cross Entropy: 1.38813, Val Cross Entropy: 1.44412
# Learning Rate: [1.4083220242514666e-05]
# Epoch: 212, Train Cross Entropy: 1.38794, Val Cross Entropy: 1.44376
# Learning Rate: [1.3801555837664372e-05]
# Epoch: 213, Train Cross Entropy: 1.38843, Val Cross Entropy: 1.44306
# Learning Rate: [1.3525524720911085e-05]
# Epoch: 214, Train Cross Entropy: 1.38821, Val Cross Entropy: 1.44374
# Learning Rate: [1.3255014226492864e-05]
# Epoch: 215, Train Cross Entropy: 1.38816, Val Cross Entropy: 1.44334
# Learning Rate: [1.2989913941963006e-05]
# Epoch: 216, Train Cross Entropy: 1.38779, Val Cross Entropy: 1.44369
# Learning Rate: [1.2730115663123746e-05]
# Epoch: 217, Train Cross Entropy: 1.38809, Val Cross Entropy: 1.44303
# Learning Rate: [1.247551334986127e-05]
# Epoch: 218, Train Cross Entropy: 1.38785, Val Cross Entropy: 1.44389
# Learning Rate: [1.2226003082864045e-05]
# Epoch: 219, Train Cross Entropy: 1.38794, Val Cross Entropy: 1.44332
# Learning Rate: [1.1981483021206765e-05]
# Epoch: 220, Train Cross Entropy: 1.38809, Val Cross Entropy: 1.44371
# Learning Rate: [1.1741853360782628e-05]
# Epoch: 221, Train Cross Entropy: 1.38771, Val Cross Entropy: 1.44381
# Learning Rate: [1.1507016293566975e-05]
# Epoch: 222, Train Cross Entropy: 1.38776, Val Cross Entropy: 1.44333
# Learning Rate: [1.1276875967695635e-05]
# Epoch: 223, Train Cross Entropy: 1.38795, Val Cross Entropy: 1.44308
# Learning Rate: [1.1051338448341723e-05]
# Epoch: 224, Train Cross Entropy: 1.38812, Val Cross Entropy: 1.44313
# Learning Rate: [1.0830311679374888e-05]
# Epoch: 225, Train Cross Entropy: 1.38758, Val Cross Entropy: 1.44401
# Learning Rate: [1.061370544578739e-05]
# Epoch: 226, Train Cross Entropy: 1.38761, Val Cross Entropy: 1.44292
# Learning Rate: [1.0401431336871642e-05]
# Epoch: 227, Train Cross Entropy: 1.38766, Val Cross Entropy: 1.44324
# Learning Rate: [1.0193402710134209e-05]
# Epoch: 228, Train Cross Entropy: 1.38776, Val Cross Entropy: 1.44344
# Learning Rate: [9.989534655931524e-06]
# Epoch: 229, Train Cross Entropy: 1.38761, Val Cross Entropy: 1.44293
# Learning Rate: [9.789743962812893e-06]
# Epoch: 230, Train Cross Entropy: 1.38777, Val Cross Entropy: 1.44378
# Learning Rate: [9.593949083556634e-06]
# Epoch: 231, Train Cross Entropy: 1.38772, Val Cross Entropy: 1.44328
# Learning Rate: [9.402070101885501e-06]
# Epoch: 232, Train Cross Entropy: 1.3874, Val Cross Entropy: 1.44355
# Learning Rate: [9.214028699847791e-06]
# Epoch: 233, Train Cross Entropy: 1.38777, Val Cross Entropy: 1.44351
# Learning Rate: [9.029748125850835e-06]
# Epoch: 234, Train Cross Entropy: 1.38748, Val Cross Entropy: 1.44328
# Learning Rate: [8.849153163333817e-06]
# Epoch: 235, Train Cross Entropy: 1.38745, Val Cross Entropy: 1.4434
# Learning Rate: [8.67217010006714e-06]
# Epoch: 236, Train Cross Entropy: 1.38785, Val Cross Entropy: 1.44288
# Learning Rate: [8.498726698065798e-06]
# Epoch: 237, Train Cross Entropy: 1.38765, Val Cross Entropy: 1.44309
# Learning Rate: [8.328752164104483e-06]
# Epoch: 238, Train Cross Entropy: 1.38748, Val Cross Entropy: 1.44309
# Learning Rate: [8.162177120822392e-06]
# Epoch: 239, Train Cross Entropy: 1.38746, Val Cross Entropy: 1.44345
# Learning Rate: [7.998933578405944e-06]
# Epoch: 240, Train Cross Entropy: 1.38758, Val Cross Entropy: 1.44317
# Learning Rate: [7.838954906837825e-06]
# Epoch: 241, Train Cross Entropy: 1.38785, Val Cross Entropy: 1.44302
# Learning Rate: [7.682175808701068e-06]
# Epoch: 242, Train Cross Entropy: 1.38728, Val Cross Entropy: 1.44341
# Learning Rate: [7.528532292527047e-06]
# Epoch: 243, Train Cross Entropy: 1.38761, Val Cross Entropy: 1.44317
# Learning Rate: [7.377961646676505e-06]
# Epoch: 244, Train Cross Entropy: 1.3877, Val Cross Entropy: 1.44319
# Learning Rate: [7.230402413742975e-06]
# Epoch: 245, Train Cross Entropy: 1.38752, Val Cross Entropy: 1.44298
# Learning Rate: [7.085794365468116e-06]
# Epoch: 246, Train Cross Entropy: 1.38756, Val Cross Entropy: 1.44329
# Learning Rate: [6.944078478158754e-06]
# Epoch: 247, Train Cross Entropy: 1.38725, Val Cross Entropy: 1.4429
# Learning Rate: [6.805196908595578e-06]
# Epoch: 248, Train Cross Entropy: 1.38734, Val Cross Entropy: 1.44307
# Learning Rate: [6.669092970423666e-06]
# Epoch: 249, Train Cross Entropy: 1.38733, Val Cross Entropy: 1.44301
# Learning Rate: [6.5357111110151925e-06]
# Epoch: 250, Train Cross Entropy: 1.38687, Val Cross Entropy: 1.44297
# Learning Rate: [6.404996888794888e-06]
# fold 2
# Using device 'cuda'
# Epoch: 1, Train Cross Entropy: 1.65479, Val Cross Entropy: 1.65518
# Learning Rate: [0.00098]
# Epoch: 2, Train Cross Entropy: 1.61233, Val Cross Entropy: 1.61492
# Learning Rate: [0.0009603999999999999]
# Epoch: 3, Train Cross Entropy: 1.58748, Val Cross Entropy: 1.59119
# Learning Rate: [0.0009411919999999999]
# Epoch: 4, Train Cross Entropy: 1.57616, Val Cross Entropy: 1.58065
# Learning Rate: [0.0009223681599999998]
# Epoch: 5, Train Cross Entropy: 1.56494, Val Cross Entropy: 1.56976
# Learning Rate: [0.0009039207967999998]
# Epoch: 6, Train Cross Entropy: 1.55434, Val Cross Entropy: 1.56133
# Learning Rate: [0.0008858423808639998]
# Epoch: 7, Train Cross Entropy: 1.54614, Val Cross Entropy: 1.55378
# Learning Rate: [0.0008681255332467198]
# Epoch: 8, Train Cross Entropy: 1.54006, Val Cross Entropy: 1.54858
# Learning Rate: [0.0008507630225817853]
# Epoch: 9, Train Cross Entropy: 1.53359, Val Cross Entropy: 1.5428
# Learning Rate: [0.0008337477621301496]
# Epoch: 10, Train Cross Entropy: 1.52578, Val Cross Entropy: 1.53659
# Learning Rate: [0.0008170728068875465]
# Epoch: 11, Train Cross Entropy: 1.5211, Val Cross Entropy: 1.53352
# Learning Rate: [0.0008007313507497956]
# Epoch: 12, Train Cross Entropy: 1.51533, Val Cross Entropy: 1.52755
# Learning Rate: [0.0007847167237347997]
# Epoch: 13, Train Cross Entropy: 1.51344, Val Cross Entropy: 1.52637
# Learning Rate: [0.0007690223892601037]
# Epoch: 14, Train Cross Entropy: 1.50808, Val Cross Entropy: 1.52252
# Learning Rate: [0.0007536419414749016]
# Epoch: 15, Train Cross Entropy: 1.50393, Val Cross Entropy: 1.52026
# Learning Rate: [0.0007385691026454036]
# Epoch: 16, Train Cross Entropy: 1.49909, Val Cross Entropy: 1.51457
# Learning Rate: [0.0007237977205924955]
# Epoch: 17, Train Cross Entropy: 1.49647, Val Cross Entropy: 1.51341
# Learning Rate: [0.0007093217661806456]
# Epoch: 18, Train Cross Entropy: 1.49406, Val Cross Entropy: 1.51095
# Learning Rate: [0.0006951353308570327]
# Epoch: 19, Train Cross Entropy: 1.48917, Val Cross Entropy: 1.50728
# Learning Rate: [0.000681232624239892]
# Epoch: 20, Train Cross Entropy: 1.48578, Val Cross Entropy: 1.50578
# Learning Rate: [0.0006676079717550942]
# Epoch: 21, Train Cross Entropy: 1.48288, Val Cross Entropy: 1.50305
# Learning Rate: [0.0006542558123199924]
# Epoch: 22, Train Cross Entropy: 1.48152, Val Cross Entropy: 1.50269
# Learning Rate: [0.0006411706960735925]
# Epoch: 23, Train Cross Entropy: 1.47709, Val Cross Entropy: 1.50003
# Learning Rate: [0.0006283472821521206]
# Epoch: 24, Train Cross Entropy: 1.47782, Val Cross Entropy: 1.50001
# Learning Rate: [0.0006157803365090782]
# Epoch: 25, Train Cross Entropy: 1.47327, Val Cross Entropy: 1.49636
# Learning Rate: [0.0006034647297788967]
# Epoch: 26, Train Cross Entropy: 1.46955, Val Cross Entropy: 1.49374
# Learning Rate: [0.0005913954351833187]
# Epoch: 27, Train Cross Entropy: 1.46972, Val Cross Entropy: 1.49636
# Learning Rate: [0.0005795675264796523]
# Epoch: 28, Train Cross Entropy: 1.46792, Val Cross Entropy: 1.4924
# Learning Rate: [0.0005679761759500593]
# Epoch: 29, Train Cross Entropy: 1.46397, Val Cross Entropy: 1.49095
# Learning Rate: [0.0005566166524310581]
# Epoch: 30, Train Cross Entropy: 1.46273, Val Cross Entropy: 1.48996
# Learning Rate: [0.0005454843193824369]
# Epoch: 31, Train Cross Entropy: 1.46172, Val Cross Entropy: 1.48915
# Learning Rate: [0.0005345746329947881]
# Epoch: 32, Train Cross Entropy: 1.45882, Val Cross Entropy: 1.48752
# Learning Rate: [0.0005238831403348923]
# Epoch: 33, Train Cross Entropy: 1.45813, Val Cross Entropy: 1.48565
# Learning Rate: [0.0005134054775281945]
# Epoch: 34, Train Cross Entropy: 1.45811, Val Cross Entropy: 1.48567
# Learning Rate: [0.0005031373679776305]
# Epoch: 35, Train Cross Entropy: 1.45546, Val Cross Entropy: 1.48675
# Learning Rate: [0.0004930746206180779]
# Epoch: 36, Train Cross Entropy: 1.45156, Val Cross Entropy: 1.48261
# Learning Rate: [0.00048321312820571636]
# Epoch: 37, Train Cross Entropy: 1.45115, Val Cross Entropy: 1.48054
# Learning Rate: [0.00047354886564160203]
# Epoch: 38, Train Cross Entropy: 1.44873, Val Cross Entropy: 1.47873
# Learning Rate: [0.00046407788832877]
# Epoch: 39, Train Cross Entropy: 1.44946, Val Cross Entropy: 1.48037
# Learning Rate: [0.0004547963305621946]
# Epoch: 40, Train Cross Entropy: 1.44601, Val Cross Entropy: 1.47891
# Learning Rate: [0.0004457004039509507]
# Epoch: 41, Train Cross Entropy: 1.44514, Val Cross Entropy: 1.47771
# Learning Rate: [0.0004367863958719317]
# Epoch: 42, Train Cross Entropy: 1.44566, Val Cross Entropy: 1.47799
# Learning Rate: [0.00042805066795449306]
# Epoch: 43, Train Cross Entropy: 1.44631, Val Cross Entropy: 1.47681
# Learning Rate: [0.0004194896545954032]
# Epoch: 44, Train Cross Entropy: 1.4411, Val Cross Entropy: 1.47675
# Learning Rate: [0.0004110998615034951]
# Epoch: 45, Train Cross Entropy: 1.43887, Val Cross Entropy: 1.47625
# Learning Rate: [0.00040287786427342523]
# Epoch: 46, Train Cross Entropy: 1.43933, Val Cross Entropy: 1.47778
# Learning Rate: [0.00039482030698795675]
# Epoch: 47, Train Cross Entropy: 1.43905, Val Cross Entropy: 1.47745
# Learning Rate: [0.0003869239008481976]
# Epoch: 48, Train Cross Entropy: 1.43719, Val Cross Entropy: 1.47431
# Learning Rate: [0.0003791854228312336]
# Epoch: 49, Train Cross Entropy: 1.43552, Val Cross Entropy: 1.47269
# Learning Rate: [0.00037160171437460894]
# Epoch: 50, Train Cross Entropy: 1.43453, Val Cross Entropy: 1.47082
# Learning Rate: [0.00036416968008711674]
# Epoch: 51, Train Cross Entropy: 1.43392, Val Cross Entropy: 1.46945
# Learning Rate: [0.0003568862864853744]
# Epoch: 52, Train Cross Entropy: 1.4324, Val Cross Entropy: 1.47036
# Learning Rate: [0.0003497485607556669]
# Epoch: 53, Train Cross Entropy: 1.43166, Val Cross Entropy: 1.47071
# Learning Rate: [0.00034275358954055353]
# Epoch: 54, Train Cross Entropy: 1.42984, Val Cross Entropy: 1.4675
# Learning Rate: [0.00033589851774974244]
# Epoch: 55, Train Cross Entropy: 1.42908, Val Cross Entropy: 1.46825
# Learning Rate: [0.0003291805473947476]
# Epoch: 56, Train Cross Entropy: 1.42992, Val Cross Entropy: 1.47091
# Learning Rate: [0.0003225969364468526]
# Epoch: 57, Train Cross Entropy: 1.42751, Val Cross Entropy: 1.46763
# Learning Rate: [0.00031614499771791553]
# Epoch: 58, Train Cross Entropy: 1.42572, Val Cross Entropy: 1.46623
# Learning Rate: [0.0003098220977635572]
# Epoch: 59, Train Cross Entropy: 1.42688, Val Cross Entropy: 1.46844
# Learning Rate: [0.00030362565580828606]
# Epoch: 60, Train Cross Entropy: 1.42573, Val Cross Entropy: 1.46637
# Learning Rate: [0.0002975531426921203]
# Epoch: 61, Train Cross Entropy: 1.42374, Val Cross Entropy: 1.46578
# Learning Rate: [0.0002916020798382779]
# Epoch: 62, Train Cross Entropy: 1.42225, Val Cross Entropy: 1.46436
# Learning Rate: [0.0002857700382415123]
# Epoch: 63, Train Cross Entropy: 1.42199, Val Cross Entropy: 1.46275
# Learning Rate: [0.0002800546374766821]
# Epoch: 64, Train Cross Entropy: 1.42165, Val Cross Entropy: 1.46371
# Learning Rate: [0.00027445354472714845]
# Epoch: 65, Train Cross Entropy: 1.42113, Val Cross Entropy: 1.46485
# Learning Rate: [0.0002689644738326055]
# Epoch: 66, Train Cross Entropy: 1.41929, Val Cross Entropy: 1.46417
# Learning Rate: [0.00026358518435595335]
# Epoch: 67, Train Cross Entropy: 1.41908, Val Cross Entropy: 1.46269
# Learning Rate: [0.00025831348066883425]
# Epoch: 68, Train Cross Entropy: 1.41872, Val Cross Entropy: 1.46219
# Learning Rate: [0.00025314721105545757]
# Epoch: 69, Train Cross Entropy: 1.4185, Val Cross Entropy: 1.4631
# Learning Rate: [0.00024808426683434843]
# Epoch: 70, Train Cross Entropy: 1.41755, Val Cross Entropy: 1.4628
# Learning Rate: [0.00024312258149766146]
# Epoch: 71, Train Cross Entropy: 1.4177, Val Cross Entropy: 1.46206
# Learning Rate: [0.00023826012986770823]
# Epoch: 72, Train Cross Entropy: 1.41603, Val Cross Entropy: 1.4602
# Learning Rate: [0.00023349492727035406]
# Epoch: 73, Train Cross Entropy: 1.41601, Val Cross Entropy: 1.46068
# Learning Rate: [0.00022882502872494697]
# Epoch: 74, Train Cross Entropy: 1.41639, Val Cross Entropy: 1.45974
# Learning Rate: [0.00022424852815044804]
# Epoch: 75, Train Cross Entropy: 1.41432, Val Cross Entropy: 1.46022
# Learning Rate: [0.00021976355758743907]
# Epoch: 76, Train Cross Entropy: 1.4124, Val Cross Entropy: 1.45827
# Learning Rate: [0.00021536828643569029]
# Epoch: 77, Train Cross Entropy: 1.41341, Val Cross Entropy: 1.45737
# Learning Rate: [0.00021106092070697648]
# Epoch: 78, Train Cross Entropy: 1.41245, Val Cross Entropy: 1.4577
# Learning Rate: [0.00020683970229283695]
# Epoch: 79, Train Cross Entropy: 1.4126, Val Cross Entropy: 1.45902
# Learning Rate: [0.0002027029082469802]
# Epoch: 80, Train Cross Entropy: 1.41187, Val Cross Entropy: 1.4602
# Learning Rate: [0.0001986488500820406]
# Epoch: 81, Train Cross Entropy: 1.41101, Val Cross Entropy: 1.45792
# Learning Rate: [0.00019467587308039978]
# Epoch: 82, Train Cross Entropy: 1.41132, Val Cross Entropy: 1.45663
# Learning Rate: [0.00019078235561879178]
# Epoch: 83, Train Cross Entropy: 1.40926, Val Cross Entropy: 1.45667
# Learning Rate: [0.00018696670850641594]
# Epoch: 84, Train Cross Entropy: 1.40847, Val Cross Entropy: 1.45552
# Learning Rate: [0.0001832273743362876]
# Epoch: 85, Train Cross Entropy: 1.40879, Val Cross Entropy: 1.45626
# Learning Rate: [0.00017956282684956185]
# Epoch: 86, Train Cross Entropy: 1.4078, Val Cross Entropy: 1.45659
# Learning Rate: [0.0001759715703125706]
# Epoch: 87, Train Cross Entropy: 1.40794, Val Cross Entropy: 1.45628
# Learning Rate: [0.0001724521389063192]
# Epoch: 88, Train Cross Entropy: 1.40747, Val Cross Entropy: 1.4569
# Learning Rate: [0.00016900309612819282]
# Epoch: 89, Train Cross Entropy: 1.40613, Val Cross Entropy: 1.45565
# Learning Rate: [0.00016562303420562897]
# Epoch: 90, Train Cross Entropy: 1.40692, Val Cross Entropy: 1.45601
# Learning Rate: [0.0001623105735215164]
# Epoch: 91, Train Cross Entropy: 1.40555, Val Cross Entropy: 1.45456
# Learning Rate: [0.00015906436205108607]
# Epoch: 92, Train Cross Entropy: 1.40586, Val Cross Entropy: 1.45505
# Learning Rate: [0.00015588307481006434]
# Epoch: 93, Train Cross Entropy: 1.40571, Val Cross Entropy: 1.45541
# Learning Rate: [0.00015276541331386305]
# Epoch: 94, Train Cross Entropy: 1.40452, Val Cross Entropy: 1.45457
# Learning Rate: [0.00014971010504758578]
# Epoch: 95, Train Cross Entropy: 1.40399, Val Cross Entropy: 1.45455
# Learning Rate: [0.00014671590294663406]
# Epoch: 96, Train Cross Entropy: 1.4043, Val Cross Entropy: 1.45492
# Learning Rate: [0.00014378158488770137]
# Epoch: 97, Train Cross Entropy: 1.40441, Val Cross Entropy: 1.45309
# Learning Rate: [0.00014090595318994734]
# Epoch: 98, Train Cross Entropy: 1.40356, Val Cross Entropy: 1.45405
# Learning Rate: [0.0001380878341261484]
# Epoch: 99, Train Cross Entropy: 1.40323, Val Cross Entropy: 1.45408
# Learning Rate: [0.00013532607744362542]
# Epoch: 100, Train Cross Entropy: 1.40253, Val Cross Entropy: 1.45329
# Learning Rate: [0.00013261955589475292]
# Epoch: 101, Train Cross Entropy: 1.40268, Val Cross Entropy: 1.45285
# Learning Rate: [0.00012996716477685786]
# Epoch: 102, Train Cross Entropy: 1.40264, Val Cross Entropy: 1.45171
# Learning Rate: [0.0001273678214813207]
# Epoch: 103, Train Cross Entropy: 1.40174, Val Cross Entropy: 1.45213
# Learning Rate: [0.00012482046505169427]
# Epoch: 104, Train Cross Entropy: 1.40097, Val Cross Entropy: 1.45271
# Learning Rate: [0.00012232405575066037]
# Epoch: 105, Train Cross Entropy: 1.40099, Val Cross Entropy: 1.45291
# Learning Rate: [0.00011987757463564716]
# Epoch: 106, Train Cross Entropy: 1.40042, Val Cross Entropy: 1.45321
# Learning Rate: [0.00011748002314293422]
# Epoch: 107, Train Cross Entropy: 1.40151, Val Cross Entropy: 1.4534
# Learning Rate: [0.00011513042268007553]
# Epoch: 108, Train Cross Entropy: 1.40016, Val Cross Entropy: 1.45074
# Learning Rate: [0.00011282781422647401]
# Epoch: 109, Train Cross Entropy: 1.39951, Val Cross Entropy: 1.45229
# Learning Rate: [0.00011057125794194453]
# Epoch: 110, Train Cross Entropy: 1.39995, Val Cross Entropy: 1.4514
# Learning Rate: [0.00010835983278310564]
# Epoch: 111, Train Cross Entropy: 1.39931, Val Cross Entropy: 1.45087
# Learning Rate: [0.00010619263612744353]
# Epoch: 112, Train Cross Entropy: 1.39888, Val Cross Entropy: 1.45224
# Learning Rate: [0.00010406878340489466]
# Epoch: 113, Train Cross Entropy: 1.39807, Val Cross Entropy: 1.45243
# Learning Rate: [0.00010198740773679677]
# Epoch: 114, Train Cross Entropy: 1.39835, Val Cross Entropy: 1.45085
# Learning Rate: [9.994765958206083e-05]
# Epoch: 115, Train Cross Entropy: 1.3972, Val Cross Entropy: 1.45043
# Learning Rate: [9.79487063904196e-05]
# Epoch: 116, Train Cross Entropy: 1.39842, Val Cross Entropy: 1.45229
# Learning Rate: [9.598973226261122e-05]
# Epoch: 117, Train Cross Entropy: 1.39755, Val Cross Entropy: 1.45204
# Learning Rate: [9.4069937617359e-05]
# Epoch: 118, Train Cross Entropy: 1.39631, Val Cross Entropy: 1.45013
# Learning Rate: [9.218853886501181e-05]
# Epoch: 119, Train Cross Entropy: 1.39606, Val Cross Entropy: 1.44906
# Learning Rate: [9.034476808771157e-05]
# Epoch: 120, Train Cross Entropy: 1.39672, Val Cross Entropy: 1.44901
# Learning Rate: [8.853787272595733e-05]
# Epoch: 121, Train Cross Entropy: 1.39729, Val Cross Entropy: 1.44927
# Learning Rate: [8.676711527143819e-05]
# Epoch: 122, Train Cross Entropy: 1.39584, Val Cross Entropy: 1.449
# Learning Rate: [8.503177296600943e-05]
# Epoch: 123, Train Cross Entropy: 1.39709, Val Cross Entropy: 1.45118
# Learning Rate: [8.333113750668924e-05]
# Epoch: 124, Train Cross Entropy: 1.39557, Val Cross Entropy: 1.44995
# Learning Rate: [8.166451475655545e-05]
# Epoch: 125, Train Cross Entropy: 1.3959, Val Cross Entropy: 1.45076
# Learning Rate: [8.003122446142433e-05]
# Epoch: 126, Train Cross Entropy: 1.39518, Val Cross Entropy: 1.44901
# Learning Rate: [7.843059997219585e-05]
# Epoch: 127, Train Cross Entropy: 1.39449, Val Cross Entropy: 1.44883
# Learning Rate: [7.686198797275193e-05]
# Epoch: 128, Train Cross Entropy: 1.39422, Val Cross Entropy: 1.44968
# Learning Rate: [7.532474821329689e-05]
# Epoch: 129, Train Cross Entropy: 1.39533, Val Cross Entropy: 1.45004
# Learning Rate: [7.381825324903095e-05]
# Epoch: 130, Train Cross Entropy: 1.39432, Val Cross Entropy: 1.44834
# Learning Rate: [7.234188818405033e-05]
# Epoch: 131, Train Cross Entropy: 1.39455, Val Cross Entropy: 1.44987
# Learning Rate: [7.089505042036933e-05]
# Epoch: 132, Train Cross Entropy: 1.39384, Val Cross Entropy: 1.44975
# Learning Rate: [6.947714941196194e-05]
# Epoch: 133, Train Cross Entropy: 1.39354, Val Cross Entropy: 1.44872
# Learning Rate: [6.808760642372271e-05]
# Epoch: 134, Train Cross Entropy: 1.39406, Val Cross Entropy: 1.44798
# Learning Rate: [6.672585429524825e-05]
# Epoch: 135, Train Cross Entropy: 1.3937, Val Cross Entropy: 1.448
# Learning Rate: [6.539133720934329e-05]
# Epoch: 136, Train Cross Entropy: 1.39358, Val Cross Entropy: 1.44921
# Learning Rate: [6.408351046515642e-05]
# Epoch: 137, Train Cross Entropy: 1.39368, Val Cross Entropy: 1.44894
# Learning Rate: [6.28018402558533e-05]
# Epoch: 138, Train Cross Entropy: 1.393, Val Cross Entropy: 1.44966
# Learning Rate: [6.154580345073623e-05]
# Epoch: 139, Train Cross Entropy: 1.39285, Val Cross Entropy: 1.44958
# Learning Rate: [6.031488738172151e-05]
# Epoch: 140, Train Cross Entropy: 1.39229, Val Cross Entropy: 1.44792
# Learning Rate: [5.910858963408708e-05]
# Epoch: 141, Train Cross Entropy: 1.39322, Val Cross Entropy: 1.44795
# Learning Rate: [5.7926417841405336e-05]
# Epoch: 142, Train Cross Entropy: 1.39304, Val Cross Entropy: 1.44874
# Learning Rate: [5.676788948457723e-05]
# Epoch: 143, Train Cross Entropy: 1.3921, Val Cross Entropy: 1.44849
# Learning Rate: [5.563253169488568e-05]
# Epoch: 144, Train Cross Entropy: 1.39241, Val Cross Entropy: 1.44921
# Learning Rate: [5.4519881060987966e-05]
# Epoch: 145, Train Cross Entropy: 1.39216, Val Cross Entropy: 1.44808
# Learning Rate: [5.3429483439768204e-05]
# Epoch: 146, Train Cross Entropy: 1.39189, Val Cross Entropy: 1.44831
# Learning Rate: [5.236089377097284e-05]
# Epoch: 147, Train Cross Entropy: 1.39206, Val Cross Entropy: 1.44833
# Learning Rate: [5.131367589555338e-05]
# Epoch: 148, Train Cross Entropy: 1.39211, Val Cross Entropy: 1.44891
# Learning Rate: [5.0287402377642316e-05]
# Epoch: 149, Train Cross Entropy: 1.39128, Val Cross Entropy: 1.44798
# Learning Rate: [4.928165433008947e-05]
# Epoch: 150, Train Cross Entropy: 1.39136, Val Cross Entropy: 1.44805
# Learning Rate: [4.829602124348768e-05]
# Epoch: 151, Train Cross Entropy: 1.39074, Val Cross Entropy: 1.44741
# Learning Rate: [4.733010081861793e-05]
# Epoch: 152, Train Cross Entropy: 1.39119, Val Cross Entropy: 1.44751
# Learning Rate: [4.638349880224557e-05]
# Epoch: 153, Train Cross Entropy: 1.392, Val Cross Entropy: 1.44833
# Learning Rate: [4.5455828826200656e-05]
# Epoch: 154, Train Cross Entropy: 1.39121, Val Cross Entropy: 1.44796
# Learning Rate: [4.454671224967664e-05]
# Epoch: 155, Train Cross Entropy: 1.39059, Val Cross Entropy: 1.44725
# Learning Rate: [4.3655778004683106e-05]
# Epoch: 156, Train Cross Entropy: 1.39109, Val Cross Entropy: 1.44716
# Learning Rate: [4.278266244458944e-05]
# Epoch: 157, Train Cross Entropy: 1.39044, Val Cross Entropy: 1.44789
# Learning Rate: [4.192700919569765e-05]
# Epoch: 158, Train Cross Entropy: 1.39042, Val Cross Entropy: 1.44778
# Learning Rate: [4.10884690117837e-05]
# Epoch: 159, Train Cross Entropy: 1.39053, Val Cross Entropy: 1.44755
# Learning Rate: [4.0266699631548025e-05]
# Epoch: 160, Train Cross Entropy: 1.3903, Val Cross Entropy: 1.44622
# Learning Rate: [3.9461365638917066e-05]
# Epoch: 161, Train Cross Entropy: 1.39044, Val Cross Entropy: 1.44733
# Learning Rate: [3.867213832613872e-05]
# Epoch: 162, Train Cross Entropy: 1.38959, Val Cross Entropy: 1.4461
# Learning Rate: [3.789869555961595e-05]
# Epoch: 163, Train Cross Entropy: 1.38994, Val Cross Entropy: 1.44756
# Learning Rate: [3.714072164842363e-05]
# Epoch: 164, Train Cross Entropy: 1.38958, Val Cross Entropy: 1.44623
# Learning Rate: [3.6397907215455155e-05]
# Epoch: 165, Train Cross Entropy: 1.38962, Val Cross Entropy: 1.44659
# Learning Rate: [3.5669949071146054e-05]
# Epoch: 166, Train Cross Entropy: 1.38977, Val Cross Entropy: 1.44622
# Learning Rate: [3.495655008972313e-05]
# Epoch: 167, Train Cross Entropy: 1.38978, Val Cross Entropy: 1.44693
# Learning Rate: [3.425741908792867e-05]
# Epoch: 168, Train Cross Entropy: 1.38941, Val Cross Entropy: 1.44605
# Learning Rate: [3.3572270706170096e-05]
# Epoch: 169, Train Cross Entropy: 1.38888, Val Cross Entropy: 1.44591
# Learning Rate: [3.290082529204669e-05]
# Epoch: 170, Train Cross Entropy: 1.38911, Val Cross Entropy: 1.44652
# Learning Rate: [3.2242808786205754e-05]
# Epoch: 171, Train Cross Entropy: 1.38929, Val Cross Entropy: 1.44632
# Learning Rate: [3.1597952610481636e-05]
# Epoch: 172, Train Cross Entropy: 1.38901, Val Cross Entropy: 1.44768
# Learning Rate: [3.0965993558272005e-05]
# Epoch: 173, Train Cross Entropy: 1.38884, Val Cross Entropy: 1.44748
# Learning Rate: [3.0346673687106565e-05]
# Epoch: 174, Train Cross Entropy: 1.3887, Val Cross Entropy: 1.4473
# Learning Rate: [2.9739740213364434e-05]
# Epoch: 175, Train Cross Entropy: 1.38906, Val Cross Entropy: 1.44615
# Learning Rate: [2.9144945409097143e-05]
# Epoch: 176, Train Cross Entropy: 1.38892, Val Cross Entropy: 1.44625
# Learning Rate: [2.8562046500915198e-05]
# Epoch: 177, Train Cross Entropy: 1.38866, Val Cross Entropy: 1.44598
# Learning Rate: [2.7990805570896893e-05]
# Epoch: 178, Train Cross Entropy: 1.38826, Val Cross Entropy: 1.44643
# Learning Rate: [2.7430989459478954e-05]
# Epoch: 179, Train Cross Entropy: 1.38836, Val Cross Entropy: 1.44697
# Learning Rate: [2.6882369670289372e-05]
# Epoch: 180, Train Cross Entropy: 1.388, Val Cross Entropy: 1.4463
# Learning Rate: [2.6344722276883584e-05]
# Epoch: 181, Train Cross Entropy: 1.38806, Val Cross Entropy: 1.44578
# Learning Rate: [2.581782783134591e-05]
# Epoch: 182, Train Cross Entropy: 1.38783, Val Cross Entropy: 1.44624
# Learning Rate: [2.530147127471899e-05]
# Epoch: 183, Train Cross Entropy: 1.3885, Val Cross Entropy: 1.44535
# Learning Rate: [2.479544184922461e-05]
# Epoch: 184, Train Cross Entropy: 1.38787, Val Cross Entropy: 1.44572
# Learning Rate: [2.4299533012240118e-05]
# Epoch: 185, Train Cross Entropy: 1.38747, Val Cross Entropy: 1.44576
# Learning Rate: [2.3813542351995315e-05]
# Epoch: 186, Train Cross Entropy: 1.38806, Val Cross Entropy: 1.44566
# Learning Rate: [2.333727150495541e-05]
# Epoch: 187, Train Cross Entropy: 1.38819, Val Cross Entropy: 1.44616
# Learning Rate: [2.28705260748563e-05]
# Epoch: 188, Train Cross Entropy: 1.38822, Val Cross Entropy: 1.44579
# Learning Rate: [2.2413115553359176e-05]
# Epoch: 189, Train Cross Entropy: 1.38757, Val Cross Entropy: 1.44502
# Learning Rate: [2.196485324229199e-05]
# Epoch: 190, Train Cross Entropy: 1.38796, Val Cross Entropy: 1.4453
# Learning Rate: [2.152555617744615e-05]
# Epoch: 191, Train Cross Entropy: 1.38794, Val Cross Entropy: 1.44581
# Learning Rate: [2.109504505389723e-05]
# Epoch: 192, Train Cross Entropy: 1.38766, Val Cross Entropy: 1.44503
# Learning Rate: [2.0673144152819283e-05]
# Epoch: 193, Train Cross Entropy: 1.3874, Val Cross Entropy: 1.44538
# Learning Rate: [2.0259681269762897e-05]
# Epoch: 194, Train Cross Entropy: 1.38766, Val Cross Entropy: 1.44625
# Learning Rate: [1.985448764436764e-05]
# Epoch: 195, Train Cross Entropy: 1.38765, Val Cross Entropy: 1.44648
# Learning Rate: [1.9457397891480286e-05]
# ...
# Epoch: 104, Train Cross Entropy: 1.40114, Val Cross Entropy: 1.45676
# Learning Rate: [0.00012232405575066037]
# Epoch: 105, Train Cross Entropy: 1.40188, Val Cross Entropy: 1.45739
# Learning Rate: [0.00011987757463564716]
# Epoch: 106, Train Cross Entropy: 1.40046, Val Cross Entropy: 1.45681
# Learning Rate: [0.00011748002314293422]
# Epoch: 107, Train Cross Entropy: 1.40054, Val Cross Entropy: 1.45644
# Learning Rate: [0.00011513042268007553]
# Epoch: 108, Train Cross Entropy: 1.40046, Val Cross Entropy: 1.45519
# Learning Rate: [0.00011282781422647401]
# Epoch: 109, Train Cross Entropy: 1.39966, Val Cross Entropy: 1.45503
# Learning Rate: [0.00011057125794194453]
# Epoch: 110, Train Cross Entropy: 1.3998, Val Cross Entropy: 1.45632
# Learning Rate: [0.00010835983278310564]
# Epoch: 111, Train Cross Entropy: 1.39933, Val Cross Entropy: 1.4564
# Learning Rate: [0.00010619263612744353]
# Epoch: 112, Train Cross Entropy: 1.39982, Val Cross Entropy: 1.45783
# Learning Rate: [0.00010406878340489466]
# Epoch: 113, Train Cross Entropy: 1.39859, Val Cross Entropy: 1.4562
# Learning Rate: [0.00010198740773679677]
# Epoch: 114, Train Cross Entropy: 1.39813, Val Cross Entropy: 1.45482
# Learning Rate: [9.994765958206083e-05]
# Epoch: 115, Train Cross Entropy: 1.39905, Val Cross Entropy: 1.45463
# Learning Rate: [9.79487063904196e-05]
# Epoch: 116, Train Cross Entropy: 1.39873, Val Cross Entropy: 1.45573
# Learning Rate: [9.598973226261122e-05]
# Epoch: 117, Train Cross Entropy: 1.39745, Val Cross Entropy: 1.45493
# Learning Rate: [9.4069937617359e-05]
# Epoch: 118, Train Cross Entropy: 1.39734, Val Cross Entropy: 1.4546
# Learning Rate: [9.218853886501181e-05]
# Epoch: 119, Train Cross Entropy: 1.39738, Val Cross Entropy: 1.45645
# Learning Rate: [9.034476808771157e-05]
# Epoch: 120, Train Cross Entropy: 1.39713, Val Cross Entropy: 1.45385
# Learning Rate: [8.853787272595733e-05]
# Epoch: 121, Train Cross Entropy: 1.39718, Val Cross Entropy: 1.45468
# Learning Rate: [8.676711527143819e-05]
# Epoch: 122, Train Cross Entropy: 1.39606, Val Cross Entropy: 1.45378
# Learning Rate: [8.503177296600943e-05]
# Epoch: 123, Train Cross Entropy: 1.39666, Val Cross Entropy: 1.45495
# Learning Rate: [8.333113750668924e-05]
# Epoch: 124, Train Cross Entropy: 1.39758, Val Cross Entropy: 1.45619
# Learning Rate: [8.166451475655545e-05]
# Epoch: 125, Train Cross Entropy: 1.39596, Val Cross Entropy: 1.45332
# Learning Rate: [8.003122446142433e-05]
# Epoch: 126, Train Cross Entropy: 1.39591, Val Cross Entropy: 1.45319
# Learning Rate: [7.843059997219585e-05]
# Epoch: 127, Train Cross Entropy: 1.3955, Val Cross Entropy: 1.45286
# Learning Rate: [7.686198797275193e-05]
# Epoch: 128, Train Cross Entropy: 1.39524, Val Cross Entropy: 1.45361
# Learning Rate: [7.532474821329689e-05]
# Epoch: 129, Train Cross Entropy: 1.39533, Val Cross Entropy: 1.45366
# Learning Rate: [7.381825324903095e-05]
# Epoch: 130, Train Cross Entropy: 1.39474, Val Cross Entropy: 1.45298
# Learning Rate: [7.234188818405033e-05]
# Epoch: 131, Train Cross Entropy: 1.39497, Val Cross Entropy: 1.45409
# Learning Rate: [7.089505042036933e-05]
# Epoch: 132, Train Cross Entropy: 1.39506, Val Cross Entropy: 1.45395
# Learning Rate: [6.947714941196194e-05]
# Epoch: 133, Train Cross Entropy: 1.39434, Val Cross Entropy: 1.45255
# Learning Rate: [6.808760642372271e-05]
# Epoch: 134, Train Cross Entropy: 1.39409, Val Cross Entropy: 1.45298
# Learning Rate: [6.672585429524825e-05]
# Epoch: 135, Train Cross Entropy: 1.39411, Val Cross Entropy: 1.45312
# Learning Rate: [6.539133720934329e-05]
# Epoch: 136, Train Cross Entropy: 1.39343, Val Cross Entropy: 1.45249
# Learning Rate: [6.408351046515642e-05]
# Epoch: 137, Train Cross Entropy: 1.39336, Val Cross Entropy: 1.45233
# Learning Rate: [6.28018402558533e-05]
# Epoch: 138, Train Cross Entropy: 1.39384, Val Cross Entropy: 1.45295
# Learning Rate: [6.154580345073623e-05]
# Epoch: 139, Train Cross Entropy: 1.39384, Val Cross Entropy: 1.45365
# Learning Rate: [6.031488738172151e-05]
# Epoch: 140, Train Cross Entropy: 1.39328, Val Cross Entropy: 1.4519
# Learning Rate: [5.910858963408708e-05]
# Epoch: 141, Train Cross Entropy: 1.39357, Val Cross Entropy: 1.45134
# Learning Rate: [5.7926417841405336e-05]
# Epoch: 142, Train Cross Entropy: 1.3922, Val Cross Entropy: 1.45234
# Learning Rate: [5.676788948457723e-05]
# Epoch: 143, Train Cross Entropy: 1.39294, Val Cross Entropy: 1.4523
# Learning Rate: [5.563253169488568e-05]
# Epoch: 144, Train Cross Entropy: 1.39322, Val Cross Entropy: 1.45168
# Learning Rate: [5.4519881060987966e-05]
# Epoch: 145, Train Cross Entropy: 1.39237, Val Cross Entropy: 1.45236
# Learning Rate: [5.3429483439768204e-05]
# Epoch: 146, Train Cross Entropy: 1.39196, Val Cross Entropy: 1.45168
# Learning Rate: [5.236089377097284e-05]
# Epoch: 147, Train Cross Entropy: 1.39268, Val Cross Entropy: 1.4506
# Learning Rate: [5.131367589555338e-05]
# Epoch: 148, Train Cross Entropy: 1.39222, Val Cross Entropy: 1.45115
# Learning Rate: [5.0287402377642316e-05]
# Epoch: 149, Train Cross Entropy: 1.39229, Val Cross Entropy: 1.45197
# Learning Rate: [4.928165433008947e-05]
# Epoch: 150, Train Cross Entropy: 1.39206, Val Cross Entropy: 1.45168
# Learning Rate: [4.829602124348768e-05]
# Epoch: 151, Train Cross Entropy: 1.39139, Val Cross Entropy: 1.45202
# Learning Rate: [4.733010081861793e-05]
# Epoch: 152, Train Cross Entropy: 1.39165, Val Cross Entropy: 1.45093
# Learning Rate: [4.638349880224557e-05]
# Epoch: 153, Train Cross Entropy: 1.39159, Val Cross Entropy: 1.45093
# Learning Rate: [4.5455828826200656e-05]
# Epoch: 154, Train Cross Entropy: 1.39113, Val Cross Entropy: 1.45113
# Learning Rate: [4.454671224967664e-05]
# Epoch: 155, Train Cross Entropy: 1.39156, Val Cross Entropy: 1.45308
# Learning Rate: [4.3655778004683106e-05]
# Epoch: 156, Train Cross Entropy: 1.39091, Val Cross Entropy: 1.45149
# Learning Rate: [4.278266244458944e-05]
# Epoch: 157, Train Cross Entropy: 1.39057, Val Cross Entropy: 1.45109
# Learning Rate: [4.192700919569765e-05]
# Epoch: 158, Train Cross Entropy: 1.39156, Val Cross Entropy: 1.45107
# Learning Rate: [4.10884690117837e-05]
# Epoch: 159, Train Cross Entropy: 1.39103, Val Cross Entropy: 1.45045
# Learning Rate: [4.0266699631548025e-05]
# Epoch: 160, Train Cross Entropy: 1.39019, Val Cross Entropy: 1.45099
# Learning Rate: [3.9461365638917066e-05]
# Epoch: 161, Train Cross Entropy: 1.39093, Val Cross Entropy: 1.45026
# Learning Rate: [3.867213832613872e-05]
# Epoch: 162, Train Cross Entropy: 1.39105, Val Cross Entropy: 1.45147
# Learning Rate: [3.789869555961595e-05]
# Epoch: 163, Train Cross Entropy: 1.38992, Val Cross Entropy: 1.45151
# Learning Rate: [3.714072164842363e-05]
# Epoch: 164, Train Cross Entropy: 1.39003, Val Cross Entropy: 1.45116
# Learning Rate: [3.6397907215455155e-05]
# Epoch: 165, Train Cross Entropy: 1.39001, Val Cross Entropy: 1.45104
# Learning Rate: [3.5669949071146054e-05]
# Epoch: 166, Train Cross Entropy: 1.38981, Val Cross Entropy: 1.45143
# Learning Rate: [3.495655008972313e-05]
# Epoch: 167, Train Cross Entropy: 1.38997, Val Cross Entropy: 1.45163
# Learning Rate: [3.425741908792867e-05]
# Epoch: 168, Train Cross Entropy: 1.38978, Val Cross Entropy: 1.45119
# Learning Rate: [3.3572270706170096e-05]
# Epoch: 169, Train Cross Entropy: 1.38987, Val Cross Entropy: 1.45026
# Learning Rate: [3.290082529204669e-05]
# Epoch: 170, Train Cross Entropy: 1.38907, Val Cross Entropy: 1.45037
# Learning Rate: [3.2242808786205754e-05]
# Epoch: 171, Train Cross Entropy: 1.38946, Val Cross Entropy: 1.44963
# Learning Rate: [3.1597952610481636e-05]
# Epoch: 172, Train Cross Entropy: 1.38961, Val Cross Entropy: 1.44912
# Learning Rate: [3.0965993558272005e-05]
# Epoch: 173, Train Cross Entropy: 1.38898, Val Cross Entropy: 1.45001
# Learning Rate: [3.0346673687106565e-05]
# Epoch: 174, Train Cross Entropy: 1.38974, Val Cross Entropy: 1.45094
# Learning Rate: [2.9739740213364434e-05]
# Epoch: 175, Train Cross Entropy: 1.38974, Val Cross Entropy: 1.45073
# Learning Rate: [2.9144945409097143e-05]
# Epoch: 176, Train Cross Entropy: 1.38965, Val Cross Entropy: 1.45033
# Learning Rate: [2.8562046500915198e-05]
# Epoch: 177, Train Cross Entropy: 1.38864, Val Cross Entropy: 1.45152
# Learning Rate: [2.7990805570896893e-05]
# Epoch: 178, Train Cross Entropy: 1.3898, Val Cross Entropy: 1.45062
# Learning Rate: [2.7430989459478954e-05]
# Epoch: 179, Train Cross Entropy: 1.389, Val Cross Entropy: 1.45026
# Learning Rate: [2.6882369670289372e-05]
# Epoch: 180, Train Cross Entropy: 1.38872, Val Cross Entropy: 1.4505
# Learning Rate: [2.6344722276883584e-05]
# Epoch: 181, Train Cross Entropy: 1.38885, Val Cross Entropy: 1.44936
# Learning Rate: [2.581782783134591e-05]
# Epoch: 182, Train Cross Entropy: 1.38901, Val Cross Entropy: 1.4498
# Learning Rate: [2.530147127471899e-05]
# Epoch: 183, Train Cross Entropy: 1.38866, Val Cross Entropy: 1.45057
# Learning Rate: [2.479544184922461e-05]
# Epoch: 184, Train Cross Entropy: 1.38874, Val Cross Entropy: 1.45105
# Learning Rate: [2.4299533012240118e-05]
# Epoch: 185, Train Cross Entropy: 1.3887, Val Cross Entropy: 1.44988
# Learning Rate: [2.3813542351995315e-05]
# Epoch: 186, Train Cross Entropy: 1.38856, Val Cross Entropy: 1.44964
# Learning Rate: [2.333727150495541e-05]
# Epoch: 187, Train Cross Entropy: 1.38819, Val Cross Entropy: 1.4502
# Learning Rate: [2.28705260748563e-05]
# Epoch: 188, Train Cross Entropy: 1.38815, Val Cross Entropy: 1.44958
# Learning Rate: [2.2413115553359176e-05]
# Epoch: 189, Train Cross Entropy: 1.38856, Val Cross Entropy: 1.44929
# Learning Rate: [2.196485324229199e-05]
# Epoch: 190, Train Cross Entropy: 1.38837, Val Cross Entropy: 1.45026
# Learning Rate: [2.152555617744615e-05]
# Epoch: 191, Train Cross Entropy: 1.38821, Val Cross Entropy: 1.44918
# Learning Rate: [2.109504505389723e-05]
# Epoch: 192, Train Cross Entropy: 1.38789, Val Cross Entropy: 1.44982
# Learning Rate: [2.0673144152819283e-05]
# Epoch: 193, Train Cross Entropy: 1.38851, Val Cross Entropy: 1.44968
# Learning Rate: [2.0259681269762897e-05]
# Epoch: 194, Train Cross Entropy: 1.38803, Val Cross Entropy: 1.45092
# Learning Rate: [1.985448764436764e-05]
# Epoch: 195, Train Cross Entropy: 1.38777, Val Cross Entropy: 1.45039
# Learning Rate: [1.9457397891480286e-05]
# Epoch: 196, Train Cross Entropy: 1.38746, Val Cross Entropy: 1.44962
# Learning Rate: [1.906824993365068e-05]
# Epoch: 197, Train Cross Entropy: 1.38784, Val Cross Entropy: 1.44984
# Learning Rate: [1.8686884934977666e-05]
# Epoch: 198, Train Cross Entropy: 1.3879, Val Cross Entropy: 1.44969
# Learning Rate: [1.8313147236278114e-05]
# Epoch: 199, Train Cross Entropy: 1.38736, Val Cross Entropy: 1.44942
# Learning Rate: [1.794688429155255e-05]
# Epoch: 200, Train Cross Entropy: 1.3875, Val Cross Entropy: 1.44873
# Learning Rate: [1.75879466057215e-05]
# Epoch: 201, Train Cross Entropy: 1.38771, Val Cross Entropy: 1.44953
# Learning Rate: [1.7236187673607072e-05]
# Epoch: 202, Train Cross Entropy: 1.38748, Val Cross Entropy: 1.44951
# Learning Rate: [1.689146392013493e-05]
# Epoch: 203, Train Cross Entropy: 1.3875, Val Cross Entropy: 1.44945
# Learning Rate: [1.6553634641732232e-05]
# Epoch: 204, Train Cross Entropy: 1.38776, Val Cross Entropy: 1.45009
# Learning Rate: [1.6222561948897586e-05]
# Epoch: 205, Train Cross Entropy: 1.38772, Val Cross Entropy: 1.44871
# Learning Rate: [1.5898110709919635e-05]
# Epoch: 206, Train Cross Entropy: 1.3876, Val Cross Entropy: 1.44913
# Learning Rate: [1.5580148495721243e-05]
# Epoch: 207, Train Cross Entropy: 1.38779, Val Cross Entropy: 1.44951
# Learning Rate: [1.526854552580682e-05]
# Epoch: 208, Train Cross Entropy: 1.38763, Val Cross Entropy: 1.44957
# Learning Rate: [1.4963174615290682e-05]
# Epoch: 209, Train Cross Entropy: 1.38729, Val Cross Entropy: 1.44987
# Learning Rate: [1.4663911122984868e-05]
# Epoch: 210, Train Cross Entropy: 1.38675, Val Cross Entropy: 1.44952
# Learning Rate: [1.437063290052517e-05]
# Epoch: 211, Train Cross Entropy: 1.38774, Val Cross Entropy: 1.4497
# Learning Rate: [1.4083220242514666e-05]
# Epoch: 212, Train Cross Entropy: 1.38731, Val Cross Entropy: 1.44965
# Learning Rate: [1.3801555837664372e-05]
# Epoch: 213, Train Cross Entropy: 1.38705, Val Cross Entropy: 1.44952
# Learning Rate: [1.3525524720911085e-05]
# Epoch: 214, Train Cross Entropy: 1.38704, Val Cross Entropy: 1.44944
# Learning Rate: [1.3255014226492864e-05]
# Epoch: 215, Train Cross Entropy: 1.38712, Val Cross Entropy: 1.44923
# Learning Rate: [1.2989913941963006e-05]
# Epoch: 216, Train Cross Entropy: 1.38707, Val Cross Entropy: 1.44912
# Learning Rate: [1.2730115663123746e-05]
# Epoch: 217, Train Cross Entropy: 1.38731, Val Cross Entropy: 1.44901
# Learning Rate: [1.247551334986127e-05]
# Epoch: 218, Train Cross Entropy: 1.38715, Val Cross Entropy: 1.44932
# Learning Rate: [1.2226003082864045e-05]
# Epoch: 219, Train Cross Entropy: 1.38703, Val Cross Entropy: 1.4494
# Learning Rate: [1.1981483021206765e-05]
# Epoch: 220, Train Cross Entropy: 1.38701, Val Cross Entropy: 1.44989
# Learning Rate: [1.1741853360782628e-05]
# Epoch: 221, Train Cross Entropy: 1.38695, Val Cross Entropy: 1.44932
# Learning Rate: [1.1507016293566975e-05]
# Epoch: 222, Train Cross Entropy: 1.38705, Val Cross Entropy: 1.44938
# Learning Rate: [1.1276875967695635e-05]
# Epoch: 223, Train Cross Entropy: 1.38719, Val Cross Entropy: 1.44839
# Learning Rate: [1.1051338448341723e-05]
# Epoch: 224, Train Cross Entropy: 1.38697, Val Cross Entropy: 1.44872
# Learning Rate: [1.0830311679374888e-05]
# Epoch: 225, Train Cross Entropy: 1.38675, Val Cross Entropy: 1.44921
# Learning Rate: [1.061370544578739e-05]
# Epoch: 226, Train Cross Entropy: 1.3869, Val Cross Entropy: 1.44951
# Learning Rate: [1.0401431336871642e-05]
# Epoch: 227, Train Cross Entropy: 1.3867, Val Cross Entropy: 1.44865
# Learning Rate: [1.0193402710134209e-05]
# Epoch: 228, Train Cross Entropy: 1.38687, Val Cross Entropy: 1.44876
# Learning Rate: [9.989534655931524e-06]
# Epoch: 229, Train Cross Entropy: 1.3866, Val Cross Entropy: 1.44911
# Learning Rate: [9.789743962812893e-06]
# Epoch: 230, Train Cross Entropy: 1.38678, Val Cross Entropy: 1.4493
# Learning Rate: [9.593949083556634e-06]
# Epoch: 231, Train Cross Entropy: 1.38675, Val Cross Entropy: 1.44899
# Learning Rate: [9.402070101885501e-06]
# Epoch: 232, Train Cross Entropy: 1.38656, Val Cross Entropy: 1.44913
# Learning Rate: [9.214028699847791e-06]
# Epoch: 233, Train Cross Entropy: 1.38702, Val Cross Entropy: 1.44939
# Learning Rate: [9.029748125850835e-06]
# Epoch: 234, Train Cross Entropy: 1.3866, Val Cross Entropy: 1.44933
# Learning Rate: [8.849153163333817e-06]
# Epoch: 235, Train Cross Entropy: 1.38675, Val Cross Entropy: 1.44895
# Learning Rate: [8.67217010006714e-06]
# Epoch: 236, Train Cross Entropy: 1.38645, Val Cross Entropy: 1.44846
# Learning Rate: [8.498726698065798e-06]
# Epoch: 237, Train Cross Entropy: 1.38629, Val Cross Entropy: 1.44913
# Learning Rate: [8.328752164104483e-06]
# Epoch: 238, Train Cross Entropy: 1.38696, Val Cross Entropy: 1.44967
# Learning Rate: [8.162177120822392e-06]
# Epoch: 239, Train Cross Entropy: 1.38655, Val Cross Entropy: 1.44928
# Learning Rate: [7.998933578405944e-06]
# Epoch: 240, Train Cross Entropy: 1.38651, Val Cross Entropy: 1.4493
# Learning Rate: [7.838954906837825e-06]
# Epoch: 241, Train Cross Entropy: 1.38658, Val Cross Entropy: 1.44932
# Learning Rate: [7.682175808701068e-06]
# Epoch: 242, Train Cross Entropy: 1.38639, Val Cross Entropy: 1.44897
# Learning Rate: [7.528532292527047e-06]
# Epoch: 243, Train Cross Entropy: 1.38635, Val Cross Entropy: 1.44879
# Learning Rate: [7.377961646676505e-06]
# Epoch: 244, Train Cross Entropy: 1.38638, Val Cross Entropy: 1.44888
# Learning Rate: [7.230402413742975e-06]
# Epoch: 245, Train Cross Entropy: 1.38633, Val Cross Entropy: 1.44898
# Learning Rate: [7.085794365468116e-06]
# Epoch: 246, Train Cross Entropy: 1.38645, Val Cross Entropy: 1.44861
# Learning Rate: [6.944078478158754e-06]
# Epoch: 247, Train Cross Entropy: 1.38645, Val Cross Entropy: 1.44889
# Learning Rate: [6.805196908595578e-06]
# Epoch: 248, Train Cross Entropy: 1.38639, Val Cross Entropy: 1.44888
# Learning Rate: [6.669092970423666e-06]
# Epoch: 249, Train Cross Entropy: 1.38621, Val Cross Entropy: 1.44925
# Learning Rate: [6.5357111110151925e-06]
# Epoch: 250, Train Cross Entropy: 1.38634, Val Cross Entropy: 1.44919
# Learning Rate: [6.404996888794888e-06]
# ----------------------------------
# best epoch 235
# best mean score 1.4437573440738751

# %%
num_plot_columns = 3
fig, axes = create_plot_grid(num_folds, num_plot_columns, subplot_width=5, subplot_height=4)

for fold in range(num_folds):
    row, column = divmod(fold, num_plot_columns)
    plot_metric_curves(training_history[fold]["train_metrics"]["Cross Entropy"],
                       training_history[fold]["val_metrics"]["Cross Entropy"],
                       best_epoch=best_epoch+1,
                       title=f"fold {fold+1}", ax=axes[row][column], metric_label="Cross Entropy")

for i in range(num_folds, len(fig.axes)):
    row, column = divmod(i, num_plot_columns)
    axes[row][column].axis('off')

plt.tight_layout()

# %%
plot_metric_curves(mean_train_metric, mean_val_metric, best_epoch=best_epoch+1, metric_label="Cross Entropy")

# %% [markdown]
# ## Model training

# %%
criterion =  nn.CrossEntropyLoss()
num_epochs = 250
batch_size = 128
seed = 1

# %%
torch.manual_seed(seed)

model = TransformerGenerator(**model_params)

optimizer = torch.optim.Adam(model.parameters(), lr=0.001)
lr_scheduler = StepLR(optimizer, step_size=1, gamma=0.98)

train_dataset_wrapper = SetupsDatasetWrapper(setups_dataset, mirror_prob=mirror_prob, random_state=seed)
train_dataloader = DataLoader(train_dataset_wrapper, batch_size=batch_size, shuffle=True, generator=torch.Generator().manual_seed(seed))

metrics_per_epoch = train(model, train_dataloader, num_epochs, optimizer, criterion,
                          eval_metrics=[("Cross Entropy", log_loss_seq)],
                          callbacks=[LearningRateCallback(lr_scheduler, verbose=True)])
# Out:
# Using device 'cuda'
# Epoch: 1, Train Cross Entropy: 1.63847
# Learning Rate: [0.00098]
# Epoch: 2, Train Cross Entropy: 1.60658
# Learning Rate: [0.0009603999999999999]
# Epoch: 3, Train Cross Entropy: 1.58057
# Learning Rate: [0.0009411919999999999]
# Epoch: 4, Train Cross Entropy: 1.56855
# Learning Rate: [0.0009223681599999998]
# Epoch: 5, Train Cross Entropy: 1.55579
# Learning Rate: [0.0009039207967999998]
# Epoch: 6, Train Cross Entropy: 1.54536
# Learning Rate: [0.0008858423808639998]
# Epoch: 7, Train Cross Entropy: 1.53805
# Learning Rate: [0.0008681255332467198]
# Epoch: 8, Train Cross Entropy: 1.52981
# Learning Rate: [0.0008507630225817853]
# Epoch: 9, Train Cross Entropy: 1.52399
# Learning Rate: [0.0008337477621301496]
# Epoch: 10, Train Cross Entropy: 1.51885
# Learning Rate: [0.0008170728068875465]
# Epoch: 11, Train Cross Entropy: 1.5114
# Learning Rate: [0.0008007313507497956]
# Epoch: 12, Train Cross Entropy: 1.50715
# Learning Rate: [0.0007847167237347997]
# Epoch: 13, Train Cross Entropy: 1.50347
# Learning Rate: [0.0007690223892601037]
# Epoch: 14, Train Cross Entropy: 1.50118
# Learning Rate: [0.0007536419414749016]
# Epoch: 15, Train Cross Entropy: 1.4959
# Learning Rate: [0.0007385691026454036]
# Epoch: 16, Train Cross Entropy: 1.49167
# Learning Rate: [0.0007237977205924955]
# Epoch: 17, Train Cross Entropy: 1.4878
# Learning Rate: [0.0007093217661806456]
# Epoch: 18, Train Cross Entropy: 1.48758
# Learning Rate: [0.0006951353308570327]
# Epoch: 19, Train Cross Entropy: 1.48308
# Learning Rate: [0.000681232624239892]
# Epoch: 20, Train Cross Entropy: 1.47894
# Learning Rate: [0.0006676079717550942]
# Epoch: 21, Train Cross Entropy: 1.47949
# Learning Rate: [0.0006542558123199924]
# Epoch: 22, Train Cross Entropy: 1.4734
# Learning Rate: [0.0006411706960735925]
# Epoch: 23, Train Cross Entropy: 1.47157
# Learning Rate: [0.0006283472821521206]
# Epoch: 24, Train Cross Entropy: 1.46779
# Learning Rate: [0.0006157803365090782]
# Epoch: 25, Train Cross Entropy: 1.46645
# Learning Rate: [0.0006034647297788967]
# Epoch: 26, Train Cross Entropy: 1.46485
# Learning Rate: [0.0005913954351833187]
# Epoch: 27, Train Cross Entropy: 1.46329
# Learning Rate: [0.0005795675264796523]
# Epoch: 28, Train Cross Entropy: 1.46232
# Learning Rate: [0.0005679761759500593]
# Epoch: 29, Train Cross Entropy: 1.45957
# Learning Rate: [0.0005566166524310581]
# Epoch: 30, Train Cross Entropy: 1.45759
# Learning Rate: [0.0005454843193824369]
# Epoch: 31, Train Cross Entropy: 1.45685
# Learning Rate: [0.0005345746329947881]
# Epoch: 32, Train Cross Entropy: 1.45532
# Learning Rate: [0.0005238831403348923]
# Epoch: 33, Train Cross Entropy: 1.45104
# Learning Rate: [0.0005134054775281945]
# Epoch: 34, Train Cross Entropy: 1.45188
# Learning Rate: [0.0005031373679776305]
# Epoch: 35, Train Cross Entropy: 1.44959
# Learning Rate: [0.0004930746206180779]
# Epoch: 36, Train Cross Entropy: 1.44687
# Learning Rate: [0.00048321312820571636]
# Epoch: 37, Train Cross Entropy: 1.44532
# Learning Rate: [0.00047354886564160203]
# Epoch: 38, Train Cross Entropy: 1.4465
# Learning Rate: [0.00046407788832877]
# Epoch: 39, Train Cross Entropy: 1.44284
# Learning Rate: [0.0004547963305621946]
# Epoch: 40, Train Cross Entropy: 1.44369
# Learning Rate: [0.0004457004039509507]
# Epoch: 41, Train Cross Entropy: 1.4403
# Learning Rate: [0.0004367863958719317]
# Epoch: 42, Train Cross Entropy: 1.44041
# Learning Rate: [0.00042805066795449306]
# Epoch: 43, Train Cross Entropy: 1.43926
# Learning Rate: [0.0004194896545954032]
# Epoch: 44, Train Cross Entropy: 1.43817
# Learning Rate: [0.0004110998615034951]
# Epoch: 45, Train Cross Entropy: 1.43622
# Learning Rate: [0.00040287786427342523]
# Epoch: 46, Train Cross Entropy: 1.43471
# Learning Rate: [0.00039482030698795675]
# Epoch: 47, Train Cross Entropy: 1.43492
# Learning Rate: [0.0003869239008481976]
# Epoch: 48, Train Cross Entropy: 1.43284
# Learning Rate: [0.0003791854228312336]
# Epoch: 49, Train Cross Entropy: 1.43246
# Learning Rate: [0.00037160171437460894]
# Epoch: 50, Train Cross Entropy: 1.43231
# Learning Rate: [0.00036416968008711674]
# Epoch: 51, Train Cross Entropy: 1.43003
# Learning Rate: [0.0003568862864853744]
# Epoch: 52, Train Cross Entropy: 1.42854
# Learning Rate: [0.0003497485607556669]
# Epoch: 53, Train Cross Entropy: 1.42777
# Learning Rate: [0.00034275358954055353]
# Epoch: 54, Train Cross Entropy: 1.42697
# Learning Rate: [0.00033589851774974244]
# Epoch: 55, Train Cross Entropy: 1.42677
# Learning Rate: [0.0003291805473947476]
# Epoch: 56, Train Cross Entropy: 1.4269
# Learning Rate: [0.0003225969364468526]
# Epoch: 57, Train Cross Entropy: 1.42411
# Learning Rate: [0.00031614499771791553]
# Epoch: 58, Train Cross Entropy: 1.42341
# Learning Rate: [0.0003098220977635572]
# Epoch: 59, Train Cross Entropy: 1.42204
# Learning Rate: [0.00030362565580828606]
# Epoch: 60, Train Cross Entropy: 1.42185
# Learning Rate: [0.0002975531426921203]
# Epoch: 61, Train Cross Entropy: 1.42092
# Learning Rate: [0.0002916020798382779]
# Epoch: 62, Train Cross Entropy: 1.4226
# Learning Rate: [0.0002857700382415123]
# Epoch: 63, Train Cross Entropy: 1.41942
# Learning Rate: [0.0002800546374766821]
# Epoch: 64, Train Cross Entropy: 1.41975
# Learning Rate: [0.00027445354472714845]
# Epoch: 65, Train Cross Entropy: 1.41814
# Learning Rate: [0.0002689644738326055]
# Epoch: 66, Train Cross Entropy: 1.41882
# Learning Rate: [0.00026358518435595335]
# Epoch: 67, Train Cross Entropy: 1.41936
# Learning Rate: [0.00025831348066883425]
# Epoch: 68, Train Cross Entropy: 1.41729
# Learning Rate: [0.00025314721105545757]
# Epoch: 69, Train Cross Entropy: 1.41665
# Learning Rate: [0.00024808426683434843]
# Epoch: 70, Train Cross Entropy: 1.41545
# Learning Rate: [0.00024312258149766146]
# Epoch: 71, Train Cross Entropy: 1.41595
# Learning Rate: [0.00023826012986770823]
# Epoch: 72, Train Cross Entropy: 1.41366
# Learning Rate: [0.00023349492727035406]
# Epoch: 73, Train Cross Entropy: 1.41403
# Learning Rate: [0.00022882502872494697]
# Epoch: 74, Train Cross Entropy: 1.41327
# Learning Rate: [0.00022424852815044804]
# Epoch: 75, Train Cross Entropy: 1.41126
# Learning Rate: [0.00021976355758743907]
# Epoch: 76, Train Cross Entropy: 1.41228
# Learning Rate: [0.00021536828643569029]
# Epoch: 77, Train Cross Entropy: 1.41107
# Learning Rate: [0.00021106092070697648]
# Epoch: 78, Train Cross Entropy: 1.4115
# Learning Rate: [0.00020683970229283695]
# Epoch: 79, Train Cross Entropy: 1.41106
# Learning Rate: [0.0002027029082469802]
# Epoch: 80, Train Cross Entropy: 1.41033
# Learning Rate: [0.0001986488500820406]
# Epoch: 81, Train Cross Entropy: 1.41055
# Learning Rate: [0.00019467587308039978]
# Epoch: 82, Train Cross Entropy: 1.40953
# Learning Rate: [0.00019078235561879178]
# Epoch: 83, Train Cross Entropy: 1.41122
# Learning Rate: [0.00018696670850641594]
# Epoch: 84, Train Cross Entropy: 1.4085
# Learning Rate: [0.0001832273743362876]
# Epoch: 85, Train Cross Entropy: 1.40858
# Learning Rate: [0.00017956282684956185]
# Epoch: 86, Train Cross Entropy: 1.40814
# Learning Rate: [0.0001759715703125706]
# Epoch: 87, Train Cross Entropy: 1.40708
# Learning Rate: [0.0001724521389063192]
# Epoch: 88, Train Cross Entropy: 1.40663
# Learning Rate: [0.00016900309612819282]
# Epoch: 89, Train Cross Entropy: 1.40516
# Learning Rate: [0.00016562303420562897]
# Epoch: 90, Train Cross Entropy: 1.40649
# Learning Rate: [0.0001623105735215164]
# Epoch: 91, Train Cross Entropy: 1.40524
# Learning Rate: [0.00015906436205108607]
# Epoch: 92, Train Cross Entropy: 1.40489
# Learning Rate: [0.00015588307481006434]
# Epoch: 93, Train Cross Entropy: 1.40503
# Learning Rate: [0.00015276541331386305]
# Epoch: 94, Train Cross Entropy: 1.40411
# Learning Rate: [0.00014971010504758578]
# Epoch: 95, Train Cross Entropy: 1.40448
# Learning Rate: [0.00014671590294663406]
# Epoch: 96, Train Cross Entropy: 1.40419
# Learning Rate: [0.00014378158488770137]
# Epoch: 97, Train Cross Entropy: 1.40255
# Learning Rate: [0.00014090595318994734]
# Epoch: 98, Train Cross Entropy: 1.40298
# Learning Rate: [0.0001380878341261484]
# Epoch: 99, Train Cross Entropy: 1.40288
# Learning Rate: [0.00013532607744362542]
# Epoch: 100, Train Cross Entropy: 1.40282
# Learning Rate: [0.00013261955589475292]
# Epoch: 101, Train Cross Entropy: 1.40226
# Learning Rate: [0.00012996716477685786]
# Epoch: 102, Train Cross Entropy: 1.40158
# Learning Rate: [0.0001273678214813207]
# Epoch: 103, Train Cross Entropy: 1.40187
# Learning Rate: [0.00012482046505169427]
# Epoch: 104, Train Cross Entropy: 1.40021
# Learning Rate: [0.00012232405575066037]
# Epoch: 105, Train Cross Entropy: 1.40107
# Learning Rate: [0.00011987757463564716]
# Epoch: 106, Train Cross Entropy: 1.40183
# Learning Rate: [0.00011748002314293422]
# Epoch: 107, Train Cross Entropy: 1.40077
# Learning Rate: [0.00011513042268007553]
# Epoch: 108, Train Cross Entropy: 1.40106
# Learning Rate: [0.00011282781422647401]
# Epoch: 109, Train Cross Entropy: 1.39983
# Learning Rate: [0.00011057125794194453]
# Epoch: 110, Train Cross Entropy: 1.39865
# Learning Rate: [0.00010835983278310564]
# Epoch: 111, Train Cross Entropy: 1.3994
# Learning Rate: [0.00010619263612744353]
# Epoch: 112, Train Cross Entropy: 1.39815
# Learning Rate: [0.00010406878340489466]
# Epoch: 113, Train Cross Entropy: 1.39815
# Learning Rate: [0.00010198740773679677]
# Epoch: 114, Train Cross Entropy: 1.39864
# Learning Rate: [9.994765958206083e-05]
# Epoch: 115, Train Cross Entropy: 1.3983
# Learning Rate: [9.79487063904196e-05]
# Epoch: 116, Train Cross Entropy: 1.39797
# Learning Rate: [9.598973226261122e-05]
# Epoch: 117, Train Cross Entropy: 1.3979
# Learning Rate: [9.4069937617359e-05]
# Epoch: 118, Train Cross Entropy: 1.39805
# Learning Rate: [9.218853886501181e-05]
# Epoch: 119, Train Cross Entropy: 1.39678
# Learning Rate: [9.034476808771157e-05]
# Epoch: 120, Train Cross Entropy: 1.39707
# Learning Rate: [8.853787272595733e-05]
# Epoch: 121, Train Cross Entropy: 1.39702
# Learning Rate: [8.676711527143819e-05]
# Epoch: 122, Train Cross Entropy: 1.39704
# Learning Rate: [8.503177296600943e-05]
# Epoch: 123, Train Cross Entropy: 1.39755
# Learning Rate: [8.333113750668924e-05]
# Epoch: 124, Train Cross Entropy: 1.39672
# Learning Rate: [8.166451475655545e-05]
# Epoch: 125, Train Cross Entropy: 1.3962
# Learning Rate: [8.003122446142433e-05]
# Epoch: 126, Train Cross Entropy: 1.39587
# Learning Rate: [7.843059997219585e-05]
# Epoch: 127, Train Cross Entropy: 1.39525
# Learning Rate: [7.686198797275193e-05]
# Epoch: 128, Train Cross Entropy: 1.39506
# Learning Rate: [7.532474821329689e-05]
# Epoch: 129, Train Cross Entropy: 1.3954
# Learning Rate: [7.381825324903095e-05]
# Epoch: 130, Train Cross Entropy: 1.3952
# Learning Rate: [7.234188818405033e-05]
# Epoch: 131, Train Cross Entropy: 1.39488
# Learning Rate: [7.089505042036933e-05]
# Epoch: 132, Train Cross Entropy: 1.39489
# Learning Rate: [6.947714941196194e-05]
# Epoch: 133, Train Cross Entropy: 1.39441
# Learning Rate: [6.808760642372271e-05]
# Epoch: 134, Train Cross Entropy: 1.39447
# Learning Rate: [6.672585429524825e-05]
# Epoch: 135, Train Cross Entropy: 1.39473
# Learning Rate: [6.539133720934329e-05]
# Epoch: 136, Train Cross Entropy: 1.39411
# Learning Rate: [6.408351046515642e-05]
# Epoch: 137, Train Cross Entropy: 1.39432
# Learning Rate: [6.28018402558533e-05]
# Epoch: 138, Train Cross Entropy: 1.39362
# Learning Rate: [6.154580345073623e-05]
# Epoch: 139, Train Cross Entropy: 1.39377
# Learning Rate: [6.031488738172151e-05]
# Epoch: 140, Train Cross Entropy: 1.39366
# Learning Rate: [5.910858963408708e-05]
# Epoch: 141, Train Cross Entropy: 1.39387
# Learning Rate: [5.7926417841405336e-05]
# Epoch: 142, Train Cross Entropy: 1.39373
# Learning Rate: [5.676788948457723e-05]
# Epoch: 143, Train Cross Entropy: 1.39291
# Learning Rate: [5.563253169488568e-05]
# Epoch: 144, Train Cross Entropy: 1.39286
# Learning Rate: [5.4519881060987966e-05]
# Epoch: 145, Train Cross Entropy: 1.39284
# Learning Rate: [5.3429483439768204e-05]
# Epoch: 146, Train Cross Entropy: 1.39291
# Learning Rate: [5.236089377097284e-05]
# Epoch: 147, Train Cross Entropy: 1.39238
# Learning Rate: [5.131367589555338e-05]
# Epoch: 148, Train Cross Entropy: 1.393
# Learning Rate: [5.0287402377642316e-05]
# Epoch: 149, Train Cross Entropy: 1.39254
# Learning Rate: [4.928165433008947e-05]
# Epoch: 150, Train Cross Entropy: 1.39178
# Learning Rate: [4.829602124348768e-05]
# Epoch: 151, Train Cross Entropy: 1.39287
# Learning Rate: [4.733010081861793e-05]
# Epoch: 152, Train Cross Entropy: 1.39178
# Learning Rate: [4.638349880224557e-05]
# Epoch: 153, Train Cross Entropy: 1.39169
# Learning Rate: [4.5455828826200656e-05]
# Epoch: 154, Train Cross Entropy: 1.39154
# Learning Rate: [4.454671224967664e-05]
# Epoch: 155, Train Cross Entropy: 1.39171
# Learning Rate: [4.3655778004683106e-05]
# Epoch: 156, Train Cross Entropy: 1.39145
# Learning Rate: [4.278266244458944e-05]
# Epoch: 157, Train Cross Entropy: 1.391
# Learning Rate: [4.192700919569765e-05]
# Epoch: 158, Train Cross Entropy: 1.39144
# Learning Rate: [4.10884690117837e-05]
# Epoch: 159, Train Cross Entropy: 1.39149
# Learning Rate: [4.0266699631548025e-05]
# Epoch: 160, Train Cross Entropy: 1.39146
# Learning Rate: [3.9461365638917066e-05]
# Epoch: 161, Train Cross Entropy: 1.39108
# Learning Rate: [3.867213832613872e-05]
# Epoch: 162, Train Cross Entropy: 1.39151
# Learning Rate: [3.789869555961595e-05]
# Epoch: 163, Train Cross Entropy: 1.39067
# Learning Rate: [3.714072164842363e-05]
# Epoch: 164, Train Cross Entropy: 1.39095
# Learning Rate: [3.6397907215455155e-05]
# Epoch: 165, Train Cross Entropy: 1.3908
# Learning Rate: [3.5669949071146054e-05]
# Epoch: 166, Train Cross Entropy: 1.39072
# Learning Rate: [3.495655008972313e-05]
# Epoch: 167, Train Cross Entropy: 1.39071
# Learning Rate: [3.425741908792867e-05]
# Epoch: 168, Train Cross Entropy: 1.39058
# Learning Rate: [3.3572270706170096e-05]
# Epoch: 169, Train Cross Entropy: 1.39003
# Learning Rate: [3.290082529204669e-05]
# Epoch: 170, Train Cross Entropy: 1.39053
# Learning Rate: [3.2242808786205754e-05]
# Epoch: 171, Train Cross Entropy: 1.39034
# Learning Rate: [3.1597952610481636e-05]
# Epoch: 172, Train Cross Entropy: 1.39058
# Learning Rate: [3.0965993558272005e-05]
# Epoch: 173, Train Cross Entropy: 1.38998
# Learning Rate: [3.0346673687106565e-05]
# Epoch: 174, Train Cross Entropy: 1.39018
# Learning Rate: [2.9739740213364434e-05]
# Epoch: 175, Train Cross Entropy: 1.39027
# Learning Rate: [2.9144945409097143e-05]
# Epoch: 176, Train Cross Entropy: 1.39
# Learning Rate: [2.8562046500915198e-05]
# Epoch: 177, Train Cross Entropy: 1.38993
# Learning Rate: [2.7990805570896893e-05]
# Epoch: 178, Train Cross Entropy: 1.38988
# Learning Rate: [2.7430989459478954e-05]
# Epoch: 179, Train Cross Entropy: 1.38973
# Learning Rate: [2.6882369670289372e-05]
# Epoch: 180, Train Cross Entropy: 1.38943
# Learning Rate: [2.6344722276883584e-05]
# Epoch: 181, Train Cross Entropy: 1.38949
# Learning Rate: [2.581782783134591e-05]
# Epoch: 182, Train Cross Entropy: 1.38981
# Learning Rate: [2.530147127471899e-05]
# Epoch: 183, Train Cross Entropy: 1.38945
# Learning Rate: [2.479544184922461e-05]
# Epoch: 184, Train Cross Entropy: 1.3896
# Learning Rate: [2.4299533012240118e-05]
# Epoch: 185, Train Cross Entropy: 1.38971
# Learning Rate: [2.3813542351995315e-05]
# Epoch: 186, Train Cross Entropy: 1.38945
# Learning Rate: [2.333727150495541e-05]
# Epoch: 187, Train Cross Entropy: 1.38903
# Learning Rate: [2.28705260748563e-05]
# Epoch: 188, Train Cross Entropy: 1.38917
# Learning Rate: [2.2413115553359176e-05]
# Epoch: 189, Train Cross Entropy: 1.38937
# Learning Rate: [2.196485324229199e-05]
# Epoch: 190, Train Cross Entropy: 1.38878
# Learning Rate: [2.152555617744615e-05]
# Epoch: 191, Train Cross Entropy: 1.38939
# Learning Rate: [2.109504505389723e-05]
# Epoch: 192, Train Cross Entropy: 1.38925
# Learning Rate: [2.0673144152819283e-05]
# Epoch: 193, Train Cross Entropy: 1.38907
# Learning Rate: [2.0259681269762897e-05]
# Epoch: 194, Train Cross Entropy: 1.38873
# Learning Rate: [1.985448764436764e-05]
# Epoch: 195, Train Cross Entropy: 1.38842
# Learning Rate: [1.9457397891480286e-05]
# Epoch: 196, Train Cross Entropy: 1.38861
# Learning Rate: [1.906824993365068e-05]
# Epoch: 197, Train Cross Entropy: 1.38894
# Learning Rate: [1.8686884934977666e-05]
# Epoch: 198, Train Cross Entropy: 1.38847
# Learning Rate: [1.8313147236278114e-05]
# Epoch: 199, Train Cross Entropy: 1.38876
# Learning Rate: [1.794688429155255e-05]
# Epoch: 200, Train Cross Entropy: 1.38874
# Learning Rate: [1.75879466057215e-05]
# Epoch: 201, Train Cross Entropy: 1.38892
# Learning Rate: [1.7236187673607072e-05]
# Epoch: 202, Train Cross Entropy: 1.38861
# Learning Rate: [1.689146392013493e-05]
# Epoch: 203, Train Cross Entropy: 1.38827
# Learning Rate: [1.6553634641732232e-05]
# Epoch: 204, Train Cross Entropy: 1.38868
# Learning Rate: [1.6222561948897586e-05]
# Epoch: 205, Train Cross Entropy: 1.38854
# Learning Rate: [1.5898110709919635e-05]
# Epoch: 206, Train Cross Entropy: 1.38861
# Learning Rate: [1.5580148495721243e-05]
# Epoch: 207, Train Cross Entropy: 1.38823
# Learning Rate: [1.526854552580682e-05]
# Epoch: 208, Train Cross Entropy: 1.38882
# Learning Rate: [1.4963174615290682e-05]
# Epoch: 209, Train Cross Entropy: 1.38869
# Learning Rate: [1.4663911122984868e-05]
# Epoch: 210, Train Cross Entropy: 1.38813
# Learning Rate: [1.437063290052517e-05]
# Epoch: 211, Train Cross Entropy: 1.38802
# Learning Rate: [1.4083220242514666e-05]
# Epoch: 212, Train Cross Entropy: 1.38808
# Learning Rate: [1.3801555837664372e-05]
# Epoch: 213, Train Cross Entropy: 1.3886
# Learning Rate: [1.3525524720911085e-05]
# Epoch: 214, Train Cross Entropy: 1.38825
# Learning Rate: [1.3255014226492864e-05]
# Epoch: 215, Train Cross Entropy: 1.38817
# Learning Rate: [1.2989913941963006e-05]
# Epoch: 216, Train Cross Entropy: 1.38775
# Learning Rate: [1.2730115663123746e-05]
# Epoch: 217, Train Cross Entropy: 1.38806
# Learning Rate: [1.247551334986127e-05]
# Epoch: 218, Train Cross Entropy: 1.38813
# Learning Rate: [1.2226003082864045e-05]
# Epoch: 219, Train Cross Entropy: 1.38813
# Learning Rate: [1.1981483021206765e-05]
# Epoch: 220, Train Cross Entropy: 1.38843
# Learning Rate: [1.1741853360782628e-05]
# Epoch: 221, Train Cross Entropy: 1.38786
# Learning Rate: [1.1507016293566975e-05]
# Epoch: 222, Train Cross Entropy: 1.3879
# Learning Rate: [1.1276875967695635e-05]
# Epoch: 223, Train Cross Entropy: 1.38777
# Learning Rate: [1.1051338448341723e-05]
# Epoch: 224, Train Cross Entropy: 1.38789
# Learning Rate: [1.0830311679374888e-05]
# Epoch: 225, Train Cross Entropy: 1.38772
# Learning Rate: [1.061370544578739e-05]
# Epoch: 226, Train Cross Entropy: 1.38792
# Learning Rate: [1.0401431336871642e-05]
# Epoch: 227, Train Cross Entropy: 1.38756
# Learning Rate: [1.0193402710134209e-05]
# Epoch: 228, Train Cross Entropy: 1.38767
# Learning Rate: [9.989534655931524e-06]
# Epoch: 229, Train Cross Entropy: 1.38758
# Learning Rate: [9.789743962812893e-06]
# Epoch: 230, Train Cross Entropy: 1.38765
# Learning Rate: [9.593949083556634e-06]
# Epoch: 231, Train Cross Entropy: 1.38789
# Learning Rate: [9.402070101885501e-06]
# Epoch: 232, Train Cross Entropy: 1.38807
# Learning Rate: [9.214028699847791e-06]
# Epoch: 233, Train Cross Entropy: 1.38763
# Learning Rate: [9.029748125850835e-06]
# Epoch: 234, Train Cross Entropy: 1.38765
# Learning Rate: [8.849153163333817e-06]
# Epoch: 235, Train Cross Entropy: 1.38755
# Learning Rate: [8.67217010006714e-06]
# Epoch: 236, Train Cross Entropy: 1.38752
# Learning Rate: [8.498726698065798e-06]
# Epoch: 237, Train Cross Entropy: 1.38739
# Learning Rate: [8.328752164104483e-06]
# Epoch: 238, Train Cross Entropy: 1.38755
# Learning Rate: [8.162177120822392e-06]
# Epoch: 239, Train Cross Entropy: 1.38736
# Learning Rate: [7.998933578405944e-06]
# Epoch: 240, Train Cross Entropy: 1.3873
# Learning Rate: [7.838954906837825e-06]
# Epoch: 241, Train Cross Entropy: 1.38764
# Learning Rate: [7.682175808701068e-06]
# Epoch: 242, Train Cross Entropy: 1.38741
# Learning Rate: [7.528532292527047e-06]
# Epoch: 243, Train Cross Entropy: 1.38743
# Learning Rate: [7.377961646676505e-06]
# Epoch: 244, Train Cross Entropy: 1.38755
# Learning Rate: [7.230402413742975e-06]
# Epoch: 245, Train Cross Entropy: 1.38739
# Learning Rate: [7.085794365468116e-06]
# Epoch: 246, Train Cross Entropy: 1.38737
# Learning Rate: [6.944078478158754e-06]
# Epoch: 247, Train Cross Entropy: 1.38782
# Learning Rate: [6.805196908595578e-06]
# Epoch: 248, Train Cross Entropy: 1.38714
# Learning Rate: [6.669092970423666e-06]
# Epoch: 249, Train Cross Entropy: 1.38758
# Learning Rate: [6.5357111110151925e-06]
# Epoch: 250, Train Cross Entropy: 1.38744
# Learning Rate: [6.404996888794888e-06]

# %% [markdown]
# ## Save model

# %%
save_path = f"../models/transformer_generator.pth"
save_model(save_path, model, model_params=model_params)
