# %% [markdown]
# ## Imports

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

from sklearn.model_selection import KFold

import torch
from torch import nn
from torch.utils.data import DataLoader, Subset
from torch.optim.lr_scheduler import StepLR

# %%
from stratego_setup_generator.generators import TransformerGenerator
from stratego_setup_generator.plotting import create_plot_grid
from stratego_setup_generator.training import (
    train, save_model, log_loss_seq, SetupsDataset,
    SetupsDatasetWrapper, LearningRateCallback
)

# %% [markdown]
# ## Load data

# %%
DATA_PATH = "../data/setups.csv"

setups_df = (
    pd.read_csv(DATA_PATH, header=None, dtype='uint8')
      .drop_duplicates()
      .reset_index(drop=True)
)
setups_dataset = SetupsDataset(setups_df.to_numpy())

# %% [markdown]
# ## Cross-validate parameters and number of epochs

# %%
criterion = nn.CrossEntropyLoss()
num_epochs = 150
batch_size = 128
learning_rate = 0.001
learning_rate_decay = 0.97

seed = 1
num_folds = 5

kfold = KFold(n_splits=num_folds, shuffle=True, random_state=seed)

mirror_prob = 0.4

# %%
model_params = dict(
    embedding_dim=128,
    num_layers=3,
    num_heads=8,
    dropout=0.2
)

# %%
torch.manual_seed(seed)

metrics_history = []


for fold_idx, (train_idx, val_idx) in enumerate(kfold.split(setups_dataset)):

    print(f"fold {fold_idx + 1}")

    model = TransformerGenerator(**model_params)
    optimizer = torch.optim.AdamW(model.parameters(), lr=learning_rate)
    lr_scheduler = StepLR(optimizer, step_size=1, gamma=learning_rate_decay)

    train_dataset_wrapper = SetupsDatasetWrapper(
        setups_dataset,
        mirror_prob=mirror_prob,
        random_state=seed
    )
    val_dataset_wrapper = SetupsDatasetWrapper(setups_dataset)

    train_dataloader = DataLoader(
        Subset(train_dataset_wrapper, train_idx),
        batch_size=batch_size,
        shuffle=True
    )
    val_dataloader = DataLoader(
        Subset(val_dataset_wrapper, val_idx),
        batch_size=batch_size,
        shuffle=False
    )

    metrics_per_epoch = train(
        model,
        train_dataloader,
        num_epochs,
        optimizer,
        criterion,
        val_dataloaders=[
            ("Train", train_dataloader),
            ("Validation", val_dataloader)
        ],
        val_metrics=[("LogLoss", log_loss_seq)],
        callbacks=[LearningRateCallback(lr_scheduler, verbose=False)]
    )

    metrics_history.append(metrics_per_epoch)
# Out:
# fold 1
# Using device 'cuda'
# [Epoch 1] Train: LogLoss=1.64698 | Validation: LogLoss=1.64724
# [Epoch 2] Train: LogLoss=1.60288 | Validation: LogLoss=1.60367
# [Epoch 3] Train: LogLoss=1.58134 | Validation: LogLoss=1.58298
# [Epoch 4] Train: LogLoss=1.57038 | Validation: LogLoss=1.57372
# [Epoch 5] Train: LogLoss=1.55677 | Validation: LogLoss=1.56097
# [Epoch 6] Train: LogLoss=1.55008 | Validation: LogLoss=1.55598
# [Epoch 7] Train: LogLoss=1.54134 | Validation: LogLoss=1.54855
# [Epoch 8] Train: LogLoss=1.53132 | Validation: LogLoss=1.54058
# [Epoch 9] Train: LogLoss=1.52686 | Validation: LogLoss=1.53446
# [Epoch 10] Train: LogLoss=1.51711 | Validation: LogLoss=1.52757
# [Epoch 11] Train: LogLoss=1.51237 | Validation: LogLoss=1.52336
# [Epoch 12] Train: LogLoss=1.50637 | Validation: LogLoss=1.51901
# [Epoch 13] Train: LogLoss=1.49937 | Validation: LogLoss=1.51436
# [Epoch 14] Train: LogLoss=1.49587 | Validation: LogLoss=1.51145
# ...

# %%
train_log_loss_history = [
    fold_history['Train']["LogLoss"]
    for fold_history in metrics_history
]
val_log_loss_history = [
    fold_history['Validation']["LogLoss"]
    for fold_history in metrics_history
]

best_iters = np.argmin(val_log_loss_history, axis=1)
mean_train_log_loss = np.mean(train_log_loss_history, axis=0)
mean_val_log_loss = np.mean(val_log_loss_history, axis=0)
best_mean_iter = np.argmin(mean_val_log_loss)

# %%
for fold_idx, best_iter in enumerate(best_iters):
    print(f"Fold {fold_idx + 1}: best iter={best_iter}, "
          f"best log loss={val_log_loss_history[fold_idx][best_iter]:.4f}")

print(f"Mean over folds: best iter={best_mean_iter}, "
      f"best log loss={mean_val_log_loss[best_mean_iter]:.4f}")
# Out:
# Fold 1: best iter=147, best log loss=1.4409
# Fold 2: best iter=139, best log loss=1.4429
# Fold 3: best iter=148, best log loss=1.4411
# Fold 4: best iter=145, best log loss=1.4334
# Fold 5: best iter=149, best log loss=1.4466
# Mean over folds: best iter=145, best log loss=1.4414

# %%
fig, axes = create_plot_grid(
    num_plots=num_folds,
    num_columns=3,
    subplot_width=4,
    subplot_height=3
)
axes = axes.ravel()

x_axis_values = list(range(1, num_epochs + 1))

for fold_idx, ax in zip(range(num_folds), axes):
    ax.set_xlabel("Epoch")
    ax.set_ylabel("LogLoss")
    ax.set_title(f"fold {fold_idx + 1}")
    ax.plot(x_axis_values, train_log_loss_history[fold_idx], label="Train")
    ax.plot(x_axis_values, val_log_loss_history[fold_idx], label="Validation")
    ax.legend()

for i in range(num_folds, len(axes)):
    axes[i].axis('off')

plt.tight_layout()
plt.show()

# %%
plt.figure(figsize=(5, 4))
plt.xlabel("Epoch")
plt.ylabel("LogLoss")
plt.title(f"Mean log loss over folds")
plt.plot(x_axis_values, mean_train_log_loss, label="Train")
plt.plot(x_axis_values, mean_val_log_loss, label="Validation")
plt.legend()
plt.show()

# %% [markdown]
# ## Train model

# %%
num_epochs = 150

torch.manual_seed(seed)

model = TransformerGenerator(**model_params)
optimizer = torch.optim.AdamW(model.parameters(), lr=learning_rate)
lr_scheduler = StepLR(optimizer, step_size=1, gamma=learning_rate_decay)

train_dataset_wrapper = SetupsDatasetWrapper(
    setups_dataset,
    mirror_prob=mirror_prob,
    random_state=seed
)

train_dataloader = DataLoader(
    train_dataset_wrapper,
    batch_size=batch_size,
    shuffle=True
)

metrics_per_epoch = train(
    model,
    train_dataloader,
    num_epochs,
    optimizer,
    criterion,
    val_dataloaders=[("Train", train_dataloader)],
    val_metrics=[("LogLoss", log_loss_seq)],
    callbacks=[LearningRateCallback(lr_scheduler, verbose=False)]
)
# Out:
# Using device 'cuda'
# [Epoch 1] Train: LogLoss=1.64004
# [Epoch 2] Train: LogLoss=1.59149
# [Epoch 3] Train: LogLoss=1.57363
# [Epoch 4] Train: LogLoss=1.56048
# [Epoch 5] Train: LogLoss=1.54724
# [Epoch 6] Train: LogLoss=1.54147
# [Epoch 7] Train: LogLoss=1.52976
# [Epoch 8] Train: LogLoss=1.52134
# [Epoch 9] Train: LogLoss=1.51301
# [Epoch 10] Train: LogLoss=1.50900
# [Epoch 11] Train: LogLoss=1.49995
# [Epoch 12] Train: LogLoss=1.49591
# [Epoch 13] Train: LogLoss=1.48921
# [Epoch 14] Train: LogLoss=1.48389
# [Epoch 15] Train: LogLoss=1.48084
# [Epoch 16] Train: LogLoss=1.47718
# [Epoch 17] Train: LogLoss=1.47326
# [Epoch 18] Train: LogLoss=1.46832
# [Epoch 19] Train: LogLoss=1.46543
# [Epoch 20] Train: LogLoss=1.46242
# [Epoch 21] Train: LogLoss=1.45937
# [Epoch 22] Train: LogLoss=1.45619
# [Epoch 23] Train: LogLoss=1.45580
# [Epoch 24] Train: LogLoss=1.45032
# [Epoch 25] Train: LogLoss=1.44814
# [Epoch 26] Train: LogLoss=1.44508
# [Epoch 27] Train: LogLoss=1.44563
# ...

# %% [markdown]
# ## Save model

# %%
save_path = f"../models/transformer_generator.pth"
save_model(save_path, model, model_params=model_params)
